# %% [markdown]
# # Hopper-v4 – REINFORCE & Actor-Critic
#
# This notebook trains and evaluates a control policy on the **Hopper-v4** environment from Gymnasium (the updated fork of OpenAI Gym).
#
# The Hopper is a 2D one-legged robot that has to learn how to hop forward as fast as possible without falling over. The agent only sees joint angles and velocities – it can't see the x-position directly.
#
# We implement two algorithms:
# - **REINFORCE** (Monte Carlo Policy Gradient): collect a full episode, then update the policy using the discounted returns.
# - **Actor-Critic** (TASK 3, to be implemented): instead of waiting for the full episode, we use a value function (critic) to estimate returns step by step.
#
# Works both on **Google Colab** and locally.

# %%
import sys, os, subprocess

# Check if we are running on Google Colab or locally.
IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    from google.colab import drive
    drive.mount("/content/drive")

    REPO_URL    = "https://github.com/Gianbattistabsn/FAIML-RL-26.git"
    REPO_BRANCH = "part1-gian-gabri"
    REPO_ROOT   = "/content/FAIML-RL-26"

    if not os.path.exists(REPO_ROOT):
        # Try cloning the specific branch directly.
        # Capture output so we can print the real git error if it fails.
        result = subprocess.run(
            ["git", "clone", "--branch", REPO_BRANCH, REPO_URL, REPO_ROOT],
            capture_output=True, text=True
        )
        if result.returncode != 0:
            # Fallback: clone default branch then checkout the right one
            print("Branch clone failed, falling back to clone + checkout")
            print("git stderr:", result.stderr.strip())
            subprocess.run(["git", "clone", REPO_URL, REPO_ROOT], check=True)
            subprocess.run(["git", "-C", REPO_ROOT, "checkout", REPO_BRANCH], check=True)
    else:
        # Repo already exists: fetch + checkout correct branch + pull
        subprocess.run(["git", "-C", REPO_ROOT, "fetch", "origin"], check=True)
        subprocess.run(["git", "-C", REPO_ROOT, "checkout", REPO_BRANCH], check=True)
        subprocess.run(["git", "-C", REPO_ROOT, "pull", "origin", REPO_BRANCH], check=True)

    subprocess.run(["apt-get", "install", "-y", "ffmpeg"], capture_output=True)
else:
    REPO_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))

os.chdir(REPO_ROOT)
sys.path.insert(0, os.path.join(REPO_ROOT, "part1"))

subprocess.run([sys.executable, "-m", "pip", "install", "-r", "requirements.txt", "-q"], check=False)
subprocess.run([sys.executable, "-m", "pip", "install", "pyvirtualdisplay", "-q"], check=False)

print(f"Mode      : {'Colab' if IN_COLAB else 'Local'}")
print(f"Repo root : {REPO_ROOT}")
if IN_COLAB:
    branch = subprocess.run(
        ["git", "-C", REPO_ROOT, "branch", "--show-current"],
        capture_output=True, text=True
    ).stdout.strip()
    print(f"Branch    : {branch}")
    if branch != REPO_BRANCH:
        raise RuntimeError(f"Wrong branch! Expected '{REPO_BRANCH}', got '{branch}'")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Mode      : Colab
# Repo root : /content/FAIML-RL-26
# Branch    : part1-gian-gabri

# %%
import datetime       # used to timestamp checkpoint filenames
import numpy as np    # for array operations and computing means
import gymnasium as gym  # the RL environment library
import torch          # PyTorch – used for the neural network policy
import matplotlib.pyplot as plt  # for plotting the training curve

# Import our custom Policy network and Agent class from part1/agent.py
from agent import Agent, Policy

# Start a virtual display so gymnasium can render without a physical monitor.
# This is required on Colab and on any headless machine.
# On a local machine with a desktop this will just fail silently, which is fine.
try:
    from pyvirtualdisplay import Display
    display = Display(visible=False, size=(1400, 900))
    display.start()
    print("Virtual display started")
except Exception as e:
    # No virtual display needed when running locally with a real monitor
    print(f"Virtual display not started ({e}) – that's fine if running locally")
# Out:
# Virtual display started

# %% [markdown]
# ---
# ## Environment Info
#
# Before training anything it's useful to understand what the environment actually looks like.
#
# - **State space**: the observation the agent receives at each timestep. For Hopper-v4 this is a vector of 11 continuous values (joint angles + velocities). It's a `Box` space, meaning each element can be any real number within a range.
# - **Action space**: what the agent can do. For Hopper-v4 this is a vector of 3 continuous torques (one per joint), each clipped to `[-1, 1]`.
#
# Both spaces are continuous, so we can't use simple Q-tables – we need a neural network to approximate the policy.

# %%
# Create the environment just to inspect its spaces, then close it immediately
env = gym.make('Hopper-v4')

# observation_space tells us the shape of the state vector the agent receives
# -> Box(-inf, inf, shape=(11,), dtype=float64)
print('State space  :', env.observation_space)

# action_space tells us the shape of the action vector the agent must produce
# -> Box(-1.0, 1.0, shape=(3,), dtype=float32)
print('Action space :', env.action_space)

env.close()  # always close the environment when done to free resources
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment Hopper-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# State space  : Box(-inf, inf, (11,), float64)
# Action space : Box(-1.0, 1.0, (3,), float32)

# %% [markdown]
# ---
# ## Random Policy Demo
#
# Before training, it's good to run a **random policy** as a baseline. A random policy just samples a random action at every step, completely ignoring the state. This tells us:
#
# 1. That the environment is set up correctly and we can run episodes.
# 2. What the **minimum expected reward** is (anything below this would mean our trained agent is doing worse than random, which would be a bug).
#
# Typically a random policy on Hopper-v4 gets very low rewards because the robot falls almost immediately.

# %%
# rgb_array mode returns frames as numpy arrays instead of opening a window
# (needed for headless environments like Colab)
env = gym.make('Hopper-v4', render_mode='rgb_array')

n_episodes = 3
ep_rewards = []

for ep in range(n_episodes):
    done = False
    obs, _ = env.reset()   # reset returns (observation, info) in Gymnasium
    ep_reward = 0.0

    while not done:
        # Sample a completely random action from the action space
        # This ignores the observation entirely
        action = env.action_space.sample()

        # Step the simulation: returns next obs, reward, terminated, truncated, info
        # terminated = the episode ended naturally (e.g. robot fell)
        # truncated  = the episode hit the max step limit
        obs, reward, terminated, truncated, _ = env.step(action)
        ep_reward += reward

        # The episode is over if EITHER condition is met
        done = terminated or truncated

    ep_rewards.append(ep_reward)
    print(f"Episode {ep+1}: reward = {ep_reward:.2f}")

env.close()
print(f"\nMean reward (random policy): {np.mean(ep_rewards):.2f}")
# Out:
# Episode 1: reward = 15.88
# Episode 2: reward = 21.60
# Episode 3: reward = 8.92
#
# Mean reward (random policy): 15.47

# %% [markdown]
# ---
# ## Configuration
#
# Set all hyperparameters here before running the training loop.
#
# - **ALGORITHM**: which policy gradient algorithm to use (`reinforce` or `actor_critic`).
# - **BASELINE** controls how the advantage signal is computed for REINFORCE:
#   - `-1` → **adaptive**: subtracts the moving average of the last 100 episode returns. Automatically tracks the current performance level, keeping gradients centred without manual tuning.
#   - `0` → **G_t whitening**: normalises returns to zero mean and unit std within each episode if `normalize = True`, otherwise uses constant baseline. Keeps gradient scale constant regardless of absolute reward magnitude.
#   - `>0` → **fixed constant**: subtracts a fixed value from every G_t (e.g. `20`). Simple but requires manual tuning and becomes stale as performance improves.
#   - _For `actor_critic` the baseline is unused (the critic provides the advantage directly)._
# - **NUM_EPISODES**: how many full episodes to collect. More = longer training but (hopefully) better performance.
# - **SEED**: random seed for reproducibility.
# - Checkpoints are saved every time a new best 100-episode average is found, plus once at the very end.

# %%
ALGORITHM = 'reinforce'  # 'reinforce' | 'actor_critic'

# BASELINE options for REINFORCE (ignored by actor_critic):
#   -1  → adaptive geometric: b_t = mean(last-100 G_0) * (1 - γ^(T-t)) / (1 - γ^T)
#          advantage G_t - b_t divided by std when NORMALIZE=True
#    0  → pure REINFORCE; G_t whitened (mean=0, std=1) when NORMALIZE=True
#   >0  → fixed geometric: b_t = BASELINE * (1 - γ^(T-t)) / (1 - γ^T)
BASELINE  = 0

# NORMALIZE: see markdown above for per-mode behaviour
NORMALIZE = False

# DEVICE: 'cpu' avoids CPU<->GPU transfer overhead for this small batch-size-1 workload.
# Switch to 'cuda' or 'xpu' only for significantly larger networks.
DEVICE    = 'cpu'
NUM_EPISODES = int(50e3)
SEED         = 42

# Checkpoint folder: same convention as train.py CLI so both end up in the same place
CHECKPOINT_DIR = os.path.join(REPO_ROOT, "part1", "checkpoints", f"{ALGORITHM}_baseline_{BASELINE}")
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

print(f"Algorithm   : {ALGORITHM}")
print(f"Baseline    : {BASELINE}  ({'adaptive geometric' if BASELINE == -1 else 'G_t whitening' if BASELINE == 0 else f'fixed geometric ({BASELINE})'})")
print(f"Normalize   : {NORMALIZE}")
print(f"Device      : {DEVICE}")
print(f"Episodes    : {NUM_EPISODES}")
print(f"Checkpoints : {CHECKPOINT_DIR}")
# Out:
# Algorithm   : reinforce
# Baseline    : 0  (G_t whitening)
# Normalize   : False
# Device      : cpu
# Episodes    : 50000
# Checkpoints : /content/FAIML-RL-26/part1/checkpoints/reinforce_baseline_0

# %% [markdown]
# ---
# ## Training

# %%
from train import train

# train() returns a 7-tuple:
#   policy           – trained Policy network
#   ep_rewards       – total undiscounted reward per episode
#   ep_lengths       – number of environment steps per episode
#   ep_actor_losses  – actor loss at the end of each episode
#   ep_critic_losses – critic loss per episode (mirrors actor loss for REINFORCE)
#   sigma_history    – list of (episode, σ_array) snapshots every 100 episodes
#   final_ckpt       – path to the final checkpoint saved on disk
policy, ep_rewards, ep_lengths, ep_actor_losses, ep_critic_losses, sigma_history, final_ckpt = train(
    algorithm=ALGORITHM,
    baseline=BASELINE,
    num_episodes=NUM_EPISODES,
    seed=SEED,
    checkpoint_dir=CHECKPOINT_DIR,
    normalize=NORMALIZE,
    device=DEVICE,
    learning_rate=1e-3
)
print(f"\nTraining done. Final checkpoint: {final_ckpt}")
# Out:
# Ep    100/50000 | avg:    16.6  min:     3.5  max:    53.0 | len:    17 | actor loss:  33.5633 | critic loss:  33.5633 | σ: [0.972, 0.983, 0.975] | best: -inf | elapsed: 00:00:02  (604 steps/s)
#   → New best! Saved to reinforce_best_ep100_avg17.pt
# Ep    200/50000 | avg:    32.2  min:     3.9  max:    54.4 | len:    25 | actor loss:  65.9170 | critic loss:  65.9170 | σ: [0.980, 0.978, 0.977] | best: 16.6 | elapsed: 00:00:07  (535 steps/s)
#   → New best! Saved to reinforce_best_ep200_avg32.pt
# Ep    300/50000 | avg:    48.9  min:     4.0  max:    98.5 | len:    35 | actor loss: 103.2645 | critic loss: 103.2645 | σ: [0.986, 0.976, 0.986] | best: 32.2 | elapsed: 00:00:11  (774 steps/s)
#   → New best! Saved to reinforce_best_ep300_avg49.pt
# Ep    400/50000 | avg:    46.8  min:     7.3  max:    93.8 | len:    34 | actor loss: 100.9649 | critic loss: 100.9649 | σ: [0.994, 0.982, 0.991] | best: 48.9 | elapsed: 00:00:16  (769 steps/s)
# Ep    500/50000 | avg:    40.5  min:     7.0  max:    80.5 | len:    31 | actor loss:  88.2637 | critic loss:  88.2637 | σ: [0.997, 0.978, 0.997] | best: 48.9 | elapsed: 00:00:22  (552 steps/s)
# Ep    600/50000 | avg:    49.3  min:     9.9  max:    83.7 | len:    35 | actor loss: 109.0928 | critic loss: 109.0928 | σ: [0.996, 0.982, 1.009] | best: 48.9 | elapsed: 00:00:26  (782 steps/s)
#   → New best! Saved to reinforce_best_ep600_avg49.pt
# Ep    700/50000 | avg:    54.1  min:    35.2  max:    89.0 | len:    37 | actor loss: 118.1701 | critic loss: 118.1701 | σ: [0.990, 0.975, 1.015] | best: 49.3 | elapsed: 00:00:31  (785 steps/s)
#   → New best! Saved to reinforce_best_ep700_avg54.pt
# Ep    800/50000 | avg:    30.0  min:     8.2  max:    68.9 | len:    25 | actor loss:  66.4368 | critic loss:  66.4368 | σ: [0.993, 0.977, 1.013] | best: 54.1 | elapsed: 00:00:35  (560 steps/s)
# Ep    900/50000 | avg:    26.3  min:     6.6  max:    69.9 | len:    24 | actor loss:  59.1591 | critic loss:  59.1591 | σ: [0.992, 0.983, 1.016] | best: 54.1 | elapsed: 00:00:39  (633 steps/s)
# Ep   1000/50000 | avg:    51.5  min:    17.7  max:    82.1 | len:    36 | actor loss: 115.3465 | critic loss: 115.3465 | σ: [0.987, 0.989, 1.028] | best: 54.1 | elapsed: 00:00:44  (780 steps/s)
# Ep   1100/50000 | avg:    52.1  min:    29.4  max:    79.8 | len:    36 | actor loss: 116.4536 | critic loss: 116.4536 | σ: [0.989, 0.987, 1.030] | best: 54.1 | elapsed: 00:00:49  (699 steps/s)
# Ep   1200/50000 | avg:    43.8  min:    35.2  max:    74.7 | len:    31 | actor loss: 100.0615 | critic loss: 100.0615 | σ: [0.985, 0.981, 1.035] | best: 54.1 | elapsed: 00:00:54  (605 steps/s)
# Ep   1300/50000 | avg:    40.1  min:    24.4  max:    62.7 | len:    29 | actor loss:  96.3504 | critic loss:  96.3504 | σ: [0.981, 0.987, 1.025] | best: 54.1 | elapsed: 00:00:58  (767 steps/s)
# Ep   1400/50000 | avg:    41.0  min:    28.3  max:    61.8 | len:    30 | actor loss:  97.0250 | critic loss:  97.0250 | σ: [0.981, 0.990, 1.022] | best: 54.1 | elapsed: 00:01:01  (785 steps/s)
# Ep   1500/50000 | avg:    46.7  min:    35.6  max:    68.4 | len:    34 | actor loss: 104.6383 | critic loss: 104.6383 | σ: [0.983, 0.994, 1.025] | best: 54.1 | elapsed: 00:01:07  (559 steps/s)
# Ep   1600/50000 | avg:    49.0  min:    40.7  max:    56.9 | len:    38 | actor loss: 106.8365 | critic loss: 106.8365 | σ: [0.995, 0.999, 1.019] | best: 54.1 | elapsed: 00:01:12  (766 steps/s)
# Ep   1700/50000 | avg:    45.5  min:    37.0  max:    61.9 | len:    33 | actor loss:  99.7460 | critic loss:  99.7460 | σ: [0.990, 1.001, 1.023] | best: 54.1 | elapsed: 00:01:17  (768 steps/s)
# Ep   1800/50000 | avg:    42.3  min:    34.9  max:    60.1 | len:    30 | actor loss:  94.1272 | critic loss:  94.1272 | σ: [0.994, 1.003, 1.017] | best: 54.1 | elapsed: 00:01:22  (574 steps/s)
# Ep   1900/50000 | avg:    42.8  min:    21.6  max:    66.9 | len:    31 | actor loss:  95.6126 | critic loss:  95.6126 | σ: [0.996, 1.001, 1.014] | best: 54.1 | elapsed: 00:01:26  (719 steps/s)
# Ep   2000/50000 | avg:    46.7  min:    22.4  max:    75.5 | len:    34 | actor loss: 104.4998 | critic loss: 104.4998 | σ: [0.994, 1.001, 1.008] | best: 54.1 | elapsed: 00:01:31  (743 steps/s)
# Ep   2100/50000 | avg:    41.1  min:    19.6  max:    76.2 | len:    29 | actor loss:  95.8741 | critic loss:  95.8741 | σ: [0.997, 1.008, 1.014] | best: 54.1 | elapsed: 00:01:36  (602 steps/s)
# Ep   2200/50000 | avg:    39.2  min:    17.4  max:    72.0 | len:    29 | actor loss:  89.1765 | critic loss:  89.1765 | σ: [1.003, 1.011, 1.002] | best: 54.1 | elapsed: 00:01:40  (594 steps/s)
# Ep   2300/50000 | avg:    38.2  min:    17.5  max:    76.0 | len:    29 | actor loss:  88.1336 | critic loss:  88.1336 | σ: [1.011, 1.014, 1.010] | best: 54.1 | elapsed: 00:01:44  (749 steps/s)
# Ep   2400/50000 | avg:    38.4  min:    14.1  max:    79.9 | len:    29 | actor loss:  88.0678 | critic loss:  88.0678 | σ: [1.022, 1.006, 1.017] | best: 54.1 | elapsed: 00:01:48  (733 steps/s)
# Ep   2500/50000 | avg:    31.7  min:    11.4  max:    80.5 | len:    26 | actor loss:  71.0787 | critic loss:  71.0787 | σ: [1.016, 1.010, 1.013] | best: 54.1 | elapsed: 00:01:54  (486 steps/s)
# Ep   2600/50000 | avg:    41.7  min:    16.3  max:    71.2 | len:    31 | actor loss: 101.7040 | critic loss: 101.7040 | σ: [1.019, 1.019, 1.017] | best: 54.1 | elapsed: 00:01:58  (738 steps/s)
# Ep   2700/50000 | avg:    41.5  min:    16.9  max:    82.0 | len:    29 | actor loss: 101.0315 | critic loss: 101.0315 | σ: [1.012, 1.020, 1.015] | best: 54.1 | elapsed: 00:02:02  (752 steps/s)
# Ep   2800/50000 | avg:    36.7  min:    18.3  max:    67.4 | len:    27 | actor loss:  83.9168 | critic loss:  83.9168 | σ: [1.005, 1.028, 1.007] | best: 54.1 | elapsed: 00:02:06  (618 steps/s)
# Ep   2900/50000 | avg:    38.8  min:    17.9  max:    82.4 | len:    29 | actor loss:  88.3616 | critic loss:  88.3616 | σ: [0.996, 1.014, 1.008] | best: 54.1 | elapsed: 00:02:11  (589 steps/s)
# Ep   3000/50000 | avg:    40.8  min:    20.9  max:    65.6 | len:    29 | actor loss:  98.1932 | critic loss:  98.1932 | σ: [0.997, 1.016, 1.018] | best: 54.1 | elapsed: 00:02:15  (737 steps/s)
# Ep   3100/50000 | avg:    45.2  min:    24.7  max:    70.3 | len:    32 | actor loss: 102.0563 | critic loss: 102.0563 | σ: [0.993, 1.009, 1.017] | best: 54.1 | elapsed: 00:02:19  (725 steps/s)
# Ep   3200/50000 | avg:    51.3  min:     9.5  max:    68.6 | len:    38 | actor loss: 111.6773 | critic loss: 111.6773 | σ: [0.977, 1.010, 1.011] | best: 54.1 | elapsed: 00:02:26  (577 steps/s)
# Ep   3300/50000 | avg:    48.3  min:     9.3  max:    61.8 | len:    35 | actor loss: 106.9791 | critic loss: 106.9791 | σ: [0.973, 1.026, 1.014] | best: 54.1 | elapsed: 00:02:30  (794 steps/s)
# Ep   3400/50000 | avg:    49.0  min:    41.2  max:    70.3 | len:    37 | actor loss: 105.0669 | critic loss: 105.0669 | σ: [0.963, 1.017, 1.010] | best: 54.1 | elapsed: 00:02:35  (747 steps/s)
# Ep   3500/50000 | avg:    50.0  min:    42.0  max:    68.1 | len:    39 | actor loss: 108.9353 | critic loss: 108.9353 | σ: [0.958, 1.015, 1.011] | best: 54.1 | elapsed: 00:02:42  (604 steps/s)
# Ep   3600/50000 | avg:    49.3  min:    45.1  max:    53.0 | len:    40 | actor loss: 107.2468 | critic loss: 107.2468 | σ: [0.960, 1.011, 1.018] | best: 54.1 | elapsed: 00:02:47  (790 steps/s)
# Ep   3700/50000 | avg:    48.3  min:    40.0  max:    54.2 | len:    38 | actor loss: 105.9076 | critic loss: 105.9076 | σ: [0.955, 1.014, 1.033] | best: 54.1 | elapsed: 00:02:52  (687 steps/s)
# Ep   3800/50000 | avg:    46.1  min:    38.7  max:    52.9 | len:    34 | actor loss: 102.4802 | critic loss: 102.4802 | σ: [0.950, 1.010, 1.035] | best: 54.1 | elapsed: 00:02:57  (639 steps/s)
# Ep   3900/50000 | avg:    41.6  min:    36.3  max:    64.7 | len:    29 | actor loss:  94.3919 | critic loss:  94.3919 | σ: [0.943, 1.013, 1.040] | best: 54.1 | elapsed: 00:03:01  (747 steps/s)
# Ep   4000/50000 | avg:    41.3  min:    34.7  max:    62.0 | len:    29 | actor loss:  89.5546 | critic loss:  89.5546 | σ: [0.940, 1.006, 1.043] | best: 54.1 | elapsed: 00:03:05  (757 steps/s)
# Ep   4100/50000 | avg:    42.6  min:    33.7  max:    59.7 | len:    31 | actor loss:  88.6489 | critic loss:  88.6489 | σ: [0.936, 1.010, 1.036] | best: 54.1 | elapsed: 00:03:11  (544 steps/s)
# Ep   4200/50000 | avg:    44.9  min:    33.2  max:    65.8 | len:    32 | actor loss:  93.4874 | critic loss:  93.4874 | σ: [0.932, 1.001, 1.036] | best: 54.1 | elapsed: 00:03:15  (784 steps/s)
# Ep   4300/50000 | avg:    48.6  min:    39.0  max:    58.6 | len:    35 | actor loss: 102.0622 | critic loss: 102.0622 | σ: [0.931, 0.997, 1.029] | best: 54.1 | elapsed: 00:03:19  (780 steps/s)
# Ep   4400/50000 | avg:    46.2  min:    36.8  max:    62.9 | len:    32 | actor loss:  97.4055 | critic loss:  97.4055 | σ: [0.930, 0.997, 1.029] | best: 54.1 | elapsed: 00:03:25  (570 steps/s)
# Ep   4500/50000 | avg:    43.8  min:    35.6  max:    63.4 | len:    30 | actor loss:  88.9966 | critic loss:  88.9966 | σ: [0.924, 0.997, 1.016] | best: 54.1 | elapsed: 00:03:29  (696 steps/s)
# Ep   4600/50000 | avg:    41.8  min:    34.6  max:    59.0 | len:    30 | actor loss:  85.8553 | critic loss:  85.8553 | σ: [0.927, 1.002, 1.020] | best: 54.1 | elapsed: 00:03:34  (713 steps/s)
# Ep   4700/50000 | avg:    43.4  min:    34.6  max:    55.1 | len:    30 | actor loss:  89.7604 | critic loss:  89.7604 | σ: [0.924, 1.002, 1.011] | best: 54.1 | elapsed: 00:03:38  (659 steps/s)
# Ep   4800/50000 | avg:    46.3  min:    34.7  max:    56.8 | len:    34 | actor loss:  95.6687 | critic loss:  95.6687 | σ: [0.914, 1.004, 1.012] | best: 54.1 | elapsed: 00:03:44  (636 steps/s)
# Ep   4900/50000 | avg:    43.4  min:    35.0  max:    56.9 | len:    31 | actor loss:  89.1195 | critic loss:  89.1195 | σ: [0.915, 1.006, 1.005] | best: 54.1 | elapsed: 00:03:48  (740 steps/s)
# Ep   5000/50000 | avg:    44.9  min:    34.8  max:    58.4 | len:    32 | actor loss:  92.0145 | critic loss:  92.0145 | σ: [0.902, 1.000, 0.996] | best: 54.1 | elapsed: 00:03:53  (668 steps/s)
# Ep   5100/50000 | avg:    46.4  min:    35.0  max:    78.2 | len:    33 | actor loss:  95.6800 | critic loss:  95.6800 | σ: [0.906, 0.998, 0.991] | best: 54.1 | elapsed: 00:03:58  (563 steps/s)
# Ep   5200/50000 | avg:    48.6  min:    26.0  max:    69.1 | len:    34 | actor loss:  99.4948 | critic loss:  99.4948 | σ: [0.897, 1.003, 0.989] | best: 54.1 | elapsed: 00:04:03  (753 steps/s)
# Ep   5300/50000 | avg:    48.0  min:     7.4  max:    64.7 | len:    36 | actor loss: 101.4910 | critic loss: 101.4910 | σ: [0.891, 1.006, 0.996] | best: 54.1 | elapsed: 00:04:08  (709 steps/s)
# Ep   5400/50000 | avg:    54.7  min:    11.9  max:    63.4 | len:    41 | actor loss: 116.3526 | critic loss: 116.3526 | σ: [0.891, 1.002, 0.997] | best: 54.1 | elapsed: 00:04:15  (613 steps/s)
#   → New best! Saved to reinforce_best_ep5400_avg55.pt
# Ep   5500/50000 | avg:    57.9  min:    18.6  max:    64.7 | len:    43 | actor loss: 121.6286 | critic loss: 121.6286 | σ: [0.901, 0.993, 0.999] | best: 54.7 | elapsed: 00:04:20  (758 steps/s)
#   → New best! Saved to reinforce_best_ep5500_avg58.pt
# Ep   5600/50000 | avg:    57.7  min:    16.9  max:    66.6 | len:    46 | actor loss: 121.3373 | critic loss: 121.3373 | σ: [0.903, 0.999, 1.010] | best: 57.9 | elapsed: 00:04:28  (594 steps/s)
# Ep   5700/50000 | avg:    60.6  min:    13.5  max:   187.5 | len:    59 | actor loss: 108.3789 | critic loss: 108.3789 | σ: [0.902, 0.992, 1.015] | best: 57.9 | elapsed: 00:04:35  (791 steps/s)
#   → New best! Saved to reinforce_best_ep5700_avg61.pt
# Ep   5800/50000 | avg:   102.1  min:    12.1  max:   417.3 | len:   134 | actor loss: 121.7874 | critic loss: 121.7874 | σ: [0.904, 0.993, 1.019] | best: 60.6 | elapsed: 00:04:56  (664 steps/s)
#   → New best! Saved to reinforce_best_ep5800_avg102.pt
# Ep   5900/50000 | avg:   128.3  min:    11.8  max:   356.2 | len:   164 | actor loss: 147.9150 | critic loss: 147.9150 | σ: [0.911, 0.999, 1.014] | best: 102.1 | elapsed: 00:05:21  (650 steps/s)
#   → New best! Saved to reinforce_best_ep5900_avg128.pt
# Ep   6000/50000 | avg:    72.7  min:     5.7  max:   238.6 | len:    73 | actor loss: 116.7304 | critic loss: 116.7304 | σ: [0.914, 0.993, 1.012] | best: 128.3 | elapsed: 00:05:32  (621 steps/s)
# Ep   6100/50000 | avg:    57.5  min:    10.0  max:   104.2 | len:    48 | actor loss: 113.3245 | critic loss: 113.3245 | σ: [0.913, 0.997, 1.011] | best: 128.3 | elapsed: 00:05:40  (608 steps/s)
# Ep   6200/50000 | avg:    64.9  min:    15.5  max:   171.0 | len:    58 | actor loss: 119.4031 | critic loss: 119.4031 | σ: [0.906, 1.007, 1.014] | best: 128.3 | elapsed: 00:05:50  (604 steps/s)
# Ep   6300/50000 | avg:    58.1  min:    10.3  max:   114.3 | len:    47 | actor loss: 112.2519 | critic loss: 112.2519 | σ: [0.906, 1.007, 1.002] | best: 128.3 | elapsed: 00:05:57  (660 steps/s)
# Ep   6400/50000 | avg:    58.3  min:     9.7  max:   112.0 | len:    47 | actor loss: 115.8290 | critic loss: 115.8290 | σ: [0.906, 1.009, 0.993] | best: 128.3 | elapsed: 00:06:05  (593 steps/s)
# Ep   6500/50000 | avg:    59.7  min:    17.3  max:    93.9 | len:    52 | actor loss: 114.6754 | critic loss: 114.6754 | σ: [0.895, 1.012, 0.990] | best: 128.3 | elapsed: 00:06:13  (644 steps/s)
# Ep   6600/50000 | avg:    51.9  min:    10.4  max:    79.0 | len:    46 | actor loss: 104.8426 | critic loss: 104.8426 | σ: [0.893, 1.015, 0.989] | best: 128.3 | elapsed: 00:06:21  (597 steps/s)
# Ep   6700/50000 | avg:    52.1  min:     6.8  max:    72.0 | len:    46 | actor loss: 105.6590 | critic loss: 105.6590 | σ: [0.896, 1.017, 0.984] | best: 128.3 | elapsed: 00:06:27  (685 steps/s)
# Ep   6800/50000 | avg:    51.9  min:    22.4  max:    63.1 | len:    44 | actor loss: 109.4088 | critic loss: 109.4088 | σ: [0.894, 1.028, 1.002] | best: 128.3 | elapsed: 00:06:35  (567 steps/s)
# Ep   6900/50000 | avg:    50.9  min:    15.0  max:    66.0 | len:    44 | actor loss: 105.0620 | critic loss: 105.0620 | σ: [0.894, 1.026, 0.999] | best: 128.3 | elapsed: 00:06:41  (715 steps/s)
# Ep   7000/50000 | avg:    54.6  min:     6.7  max:    81.9 | len:    45 | actor loss: 112.5789 | critic loss: 112.5789 | σ: [0.886, 1.036, 0.991] | best: 128.3 | elapsed: 00:06:49  (550 steps/s)
# Ep   7100/50000 | avg:    53.9  min:    14.7  max:   114.9 | len:    43 | actor loss: 112.7658 | critic loss: 112.7658 | σ: [0.896, 1.032, 0.977] | best: 128.3 | elapsed: 00:06:55  (719 steps/s)
# Ep   7200/50000 | avg:    53.5  min:     4.3  max:   105.7 | len:    43 | actor loss: 111.0153 | critic loss: 111.0153 | σ: [0.901, 1.026, 0.969] | best: 128.3 | elapsed: 00:07:04  (525 steps/s)
# Ep   7300/50000 | avg:    54.6  min:    28.7  max:    72.4 | len:    47 | actor loss: 110.1429 | critic loss: 110.1429 | σ: [0.897, 1.025, 0.969] | best: 128.3 | elapsed: 00:07:10  (708 steps/s)
# Ep   7400/50000 | avg:    64.2  min:     9.6  max:   118.0 | len:    60 | actor loss: 118.0855 | critic loss: 118.0855 | σ: [0.906, 1.038, 0.975] | best: 128.3 | elapsed: 00:07:20  (600 steps/s)
# Ep   7500/50000 | avg:    66.0  min:     5.1  max:   153.8 | len:    64 | actor loss: 115.7528 | critic loss: 115.7528 | σ: [0.912, 1.040, 0.986] | best: 128.3 | elapsed: 00:07:29  (749 steps/s)
# Ep   7600/50000 | avg:    70.4  min:     5.0  max:   138.3 | len:    72 | actor loss: 117.2706 | critic loss: 117.2706 | σ: [0.914, 1.036, 0.978] | best: 128.3 | elapsed: 00:07:40  (613 steps/s)
# Ep   7700/50000 | avg:    61.4  min:     4.9  max:   116.8 | len:    58 | actor loss: 112.9767 | critic loss: 112.9767 | σ: [0.919, 1.038, 0.977] | best: 128.3 | elapsed: 00:07:50  (591 steps/s)
# Ep   7800/50000 | avg:    59.7  min:     5.6  max:   114.5 | len:    54 | actor loss: 111.5672 | critic loss: 111.5672 | σ: [0.917, 1.040, 0.984] | best: 128.3 | elapsed: 00:07:58  (705 steps/s)
# Ep   7900/50000 | avg:    56.2  min:     5.2  max:   104.6 | len:    50 | actor loss: 104.3298 | critic loss: 104.3298 | σ: [0.905, 1.031, 0.984] | best: 128.3 | elapsed: 00:08:07  (573 steps/s)
# Ep   8000/50000 | avg:    60.6  min:     3.6  max:   154.6 | len:    57 | actor loss: 106.0320 | critic loss: 106.0320 | σ: [0.904, 1.026, 0.971] | best: 128.3 | elapsed: 00:08:14  (751 steps/s)
# Ep   8100/50000 | avg:    57.9  min:     4.4  max:   214.7 | len:    57 | actor loss: 102.5288 | critic loss: 102.5288 | σ: [0.903, 1.030, 0.968] | best: 128.3 | elapsed: 00:08:23  (606 steps/s)
# Ep   8200/50000 | avg:   117.9  min:     2.8  max:   655.9 | len:   163 | actor loss: 122.1086 | critic loss: 122.1086 | σ: [0.911, 1.028, 0.962] | best: 128.3 | elapsed: 00:08:46  (715 steps/s)
# Ep   8300/50000 | avg:   109.3  min:     3.9  max:   396.3 | len:   158 | actor loss: 116.7939 | critic loss: 116.7939 | σ: [0.910, 1.029, 0.968] | best: 128.3 | elapsed: 00:09:11  (650 steps/s)
# Ep   8400/50000 | avg:    83.1  min:     5.2  max:   282.2 | len:   106 | actor loss: 117.2166 | critic loss: 117.2166 | σ: [0.904, 1.029, 0.968] | best: 128.3 | elapsed: 00:09:26  (687 steps/s)
# Ep   8500/50000 | avg:    56.8  min:     4.9  max:   163.5 | len:    57 | actor loss: 106.6269 | critic loss: 106.6269 | σ: [0.904, 1.028, 0.971] | best: 128.3 | elapsed: 00:09:34  (682 steps/s)
# Ep   8600/50000 | avg:    49.5  min:    11.3  max:    97.1 | len:    45 | actor loss:  98.9821 | critic loss:  98.9821 | σ: [0.906, 1.014, 0.973] | best: 128.3 | elapsed: 00:09:41  (638 steps/s)
# Ep   8700/50000 | avg:    45.6  min:    10.6  max:    87.9 | len:    40 | actor loss:  94.7230 | critic loss:  94.7230 | σ: [0.905, 1.022, 0.972] | best: 128.3 | elapsed: 00:09:47  (755 steps/s)
# Ep   8800/50000 | avg:    46.6  min:    10.0  max:    71.1 | len:    40 | actor loss:  97.1187 | critic loss:  97.1187 | σ: [0.904, 1.016, 0.980] | best: 128.3 | elapsed: 00:09:54  (559 steps/s)
# Ep   8900/50000 | avg:    48.4  min:    10.8  max:    61.8 | len:    49 | actor loss:  91.7940 | critic loss:  91.7940 | σ: [0.903, 1.003, 0.970] | best: 128.3 | elapsed: 00:10:00  (755 steps/s)
# Ep   9000/50000 | avg:    53.2  min:    16.2  max:    78.0 | len:    58 | actor loss:  97.5174 | critic loss:  97.5174 | σ: [0.901, 1.008, 0.955] | best: 128.3 | elapsed: 00:10:10  (610 steps/s)
# Ep   9100/50000 | avg:    53.5  min:    43.7  max:    84.9 | len:    61 | actor loss:  97.2454 | critic loss:  97.2454 | σ: [0.897, 1.009, 0.962] | best: 128.3 | elapsed: 00:10:18  (773 steps/s)
# Ep   9200/50000 | avg:    48.7  min:    40.6  max:    63.7 | len:    54 | actor loss:  92.8518 | critic loss:  92.8518 | σ: [0.892, 1.002, 0.974] | best: 128.3 | elapsed: 00:10:27  (608 steps/s)
# Ep   9300/50000 | avg:    43.3  min:    39.0  max:    53.1 | len:    47 | actor loss:  88.1015 | critic loss:  88.1015 | σ: [0.889, 1.006, 0.962] | best: 128.3 | elapsed: 00:10:33  (776 steps/s)
# Ep   9400/50000 | avg:    41.7  min:    38.3  max:    45.8 | len:    44 | actor loss:  87.3864 | critic loss:  87.3864 | σ: [0.894, 1.009, 0.963] | best: 128.3 | elapsed: 00:10:40  (578 steps/s)
# Ep   9500/50000 | avg:    42.5  min:    38.1  max:    50.0 | len:    46 | actor loss:  87.8159 | critic loss:  87.8159 | σ: [0.887, 1.002, 0.962] | best: 128.3 | elapsed: 00:10:47  (729 steps/s)
# Ep   9600/50000 | avg:    44.4  min:    39.3  max:    48.3 | len:    46 | actor loss:  92.2855 | critic loss:  92.2855 | σ: [0.896, 0.995, 0.972] | best: 128.3 | elapsed: 00:10:55  (553 steps/s)
# Ep   9700/50000 | avg:    46.5  min:    42.7  max:    49.9 | len:    46 | actor loss:  97.0814 | critic loss:  97.0814 | σ: [0.910, 0.997, 0.963] | best: 128.3 | elapsed: 00:11:01  (706 steps/s)
# Ep   9800/50000 | avg:    47.9  min:    45.2  max:    52.2 | len:    46 | actor loss: 100.6106 | critic loss: 100.6106 | σ: [0.907, 0.999, 0.964] | best: 128.3 | elapsed: 00:11:09  (578 steps/s)
# Ep   9900/50000 | avg:    49.2  min:    12.6  max:    52.5 | len:    45 | actor loss: 103.6087 | critic loss: 103.6087 | σ: [0.901, 0.994, 0.966] | best: 128.3 | elapsed: 00:11:16  (693 steps/s)
# Ep  10000/50000 | avg:    49.4  min:    44.9  max:    54.1 | len:    44 | actor loss: 105.2435 | critic loss: 105.2435 | σ: [0.903, 1.001, 0.958] | best: 128.3 | elapsed: 00:11:23  (634 steps/s)
# Ep  10100/50000 | avg:    45.5  min:    41.7  max:    52.1 | len:    45 | actor loss:  98.2931 | critic loss:  98.2931 | σ: [0.908, 1.012, 0.955] | best: 128.3 | elapsed: 00:11:30  (640 steps/s)
# Ep  10200/50000 | avg:    44.4  min:    40.8  max:    75.3 | len:    46 | actor loss:  96.4170 | critic loss:  96.4170 | σ: [0.915, 1.014, 0.971] | best: 128.3 | elapsed: 00:11:37  (672 steps/s)
# Ep  10300/50000 | avg:    46.5  min:    43.5  max:    49.6 | len:    45 | actor loss:  97.8134 | critic loss:  97.8134 | σ: [0.906, 1.012, 0.967] | best: 128.3 | elapsed: 00:11:44  (587 steps/s)
# Ep  10400/50000 | avg:    44.9  min:    23.0  max:    84.1 | len:    40 | actor loss:  94.9375 | critic loss:  94.9375 | σ: [0.909, 1.012, 0.975] | best: 128.3 | elapsed: 00:11:50  (709 steps/s)
# Ep  10500/50000 | avg:    42.2  min:    11.4  max:    71.0 | len:    32 | actor loss:  91.2915 | critic loss:  91.2915 | σ: [0.906, 1.020, 0.965] | best: 128.3 | elapsed: 00:11:56  (522 steps/s)
# Ep  10600/50000 | avg:    42.1  min:     9.6  max:    79.2 | len:    32 | actor loss:  84.9893 | critic loss:  84.9893 | σ: [0.912, 1.017, 0.956] | best: 128.3 | elapsed: 00:12:01  (711 steps/s)
# Ep  10700/50000 | avg:    42.6  min:    10.6  max:    81.2 | len:    32 | actor loss:  88.7913 | critic loss:  88.7913 | σ: [0.914, 1.011, 0.951] | best: 128.3 | elapsed: 00:12:05  (742 steps/s)
# Ep  10800/50000 | avg:    39.7  min:    10.5  max:    83.5 | len:    31 | actor loss:  83.9628 | critic loss:  83.9628 | σ: [0.915, 0.999, 0.956] | best: 128.3 | elapsed: 00:12:11  (541 steps/s)
# Ep  10900/50000 | avg:    32.0  min:     8.2  max:    70.3 | len:    26 | actor loss:  68.7287 | critic loss:  68.7287 | σ: [0.914, 0.996, 0.957] | best: 128.3 | elapsed: 00:12:15  (641 steps/s)
# Ep  11000/50000 | avg:    31.9  min:     9.5  max:    56.7 | len:    25 | actor loss:  67.2026 | critic loss:  67.2026 | σ: [0.925, 1.001, 0.953] | best: 128.3 | elapsed: 00:12:18  (687 steps/s)
# Ep  11100/50000 | avg:    33.7  min:    13.9  max:    42.4 | len:    23 | actor loss:  75.9334 | critic loss:  75.9334 | σ: [0.926, 1.012, 0.951] | best: 128.3 | elapsed: 00:12:22  (735 steps/s)
# Ep  11200/50000 | avg:    36.0  min:    22.2  max:    42.7 | len:    26 | actor loss:  75.3278 | critic loss:  75.3278 | σ: [0.920, 1.015, 0.952] | best: 128.3 | elapsed: 00:12:27  (471 steps/s)
# Ep  11300/50000 | avg:    37.6  min:    31.7  max:    44.3 | len:    28 | actor loss:  72.4975 | critic loss:  72.4975 | σ: [0.921, 1.008, 0.962] | best: 128.3 | elapsed: 00:12:31  (721 steps/s)
# Ep  11400/50000 | avg:    37.1  min:    31.9  max:    43.7 | len:    28 | actor loss:  72.2374 | critic loss:  72.2374 | σ: [0.928, 1.006, 0.960] | best: 128.3 | elapsed: 00:12:35  (721 steps/s)
# Ep  11500/50000 | avg:    34.5  min:    12.6  max:    42.6 | len:    25 | actor loss:  74.2704 | critic loss:  74.2704 | σ: [0.923, 1.007, 0.965] | best: 128.3 | elapsed: 00:12:39  (622 steps/s)
# Ep  11600/50000 | avg:    34.7  min:    12.3  max:    61.4 | len:    24 | actor loss:  75.6094 | critic loss:  75.6094 | σ: [0.927, 0.990, 0.956] | best: 128.3 | elapsed: 00:12:44  (508 steps/s)
# Ep  11700/50000 | avg:    36.2  min:    21.6  max:    42.4 | len:    25 | actor loss:  78.3210 | critic loss:  78.3210 | σ: [0.935, 0.997, 0.959] | best: 128.3 | elapsed: 00:12:47  (717 steps/s)
# Ep  11800/50000 | avg:    36.2  min:    13.6  max:    56.9 | len:    25 | actor loss:  76.0039 | critic loss:  76.0039 | σ: [0.925, 0.996, 0.957] | best: 128.3 | elapsed: 00:12:51  (712 steps/s)
# Ep  11900/50000 | avg:    36.8  min:    14.6  max:    43.8 | len:    26 | actor loss:  76.9765 | critic loss:  76.9765 | σ: [0.934, 0.998, 0.953] | best: 128.3 | elapsed: 00:12:55  (572 steps/s)
# Ep  12000/50000 | avg:    35.4  min:    12.5  max:    44.1 | len:    25 | actor loss:  74.0717 | critic loss:  74.0717 | σ: [0.928, 0.988, 0.946] | best: 128.3 | elapsed: 00:13:00  (564 steps/s)
# Ep  12100/50000 | avg:    35.5  min:    12.8  max:    48.6 | len:    25 | actor loss:  73.8578 | critic loss:  73.8578 | σ: [0.920, 0.983, 0.948] | best: 128.3 | elapsed: 00:13:03  (724 steps/s)
# Ep  12200/50000 | avg:    37.4  min:    15.6  max:    46.8 | len:    27 | actor loss:  73.5757 | critic loss:  73.5757 | σ: [0.913, 0.977, 0.948] | best: 128.3 | elapsed: 00:13:07  (730 steps/s)
# Ep  12300/50000 | avg:    38.3  min:    23.1  max:    48.4 | len:    27 | actor loss:  76.3411 | critic loss:  76.3411 | σ: [0.904, 0.975, 0.953] | best: 128.3 | elapsed: 00:13:12  (538 steps/s)
# Ep  12400/50000 | avg:    37.0  min:    11.5  max:    63.4 | len:    27 | actor loss:  74.2474 | critic loss:  74.2474 | σ: [0.905, 0.969, 0.946] | best: 128.3 | elapsed: 00:13:16  (647 steps/s)
# Ep  12500/50000 | avg:    36.0  min:    30.0  max:    41.6 | len:    26 | actor loss:  72.3748 | critic loss:  72.3748 | σ: [0.904, 0.971, 0.951] | best: 128.3 | elapsed: 00:13:20  (737 steps/s)
# Ep  12600/50000 | avg:    35.2  min:    29.2  max:    42.5 | len:    27 | actor loss:  68.6322 | critic loss:  68.6322 | σ: [0.907, 0.975, 0.949] | best: 128.3 | elapsed: 00:13:23  (718 steps/s)
# Ep  12700/50000 | avg:    36.2  min:    28.9  max:    72.7 | len:    27 | actor loss:  72.0094 | critic loss:  72.0094 | σ: [0.906, 0.981, 0.945] | best: 128.3 | elapsed: 00:13:29  (479 steps/s)
# Ep  12800/50000 | avg:    37.2  min:    30.3  max:    77.2 | len:    28 | actor loss:  72.9830 | critic loss:  72.9830 | σ: [0.904, 0.971, 0.940] | best: 128.3 | elapsed: 00:13:33  (717 steps/s)
# Ep  12900/50000 | avg:    35.5  min:    28.4  max:    47.0 | len:    26 | actor loss:  74.0273 | critic loss:  74.0273 | σ: [0.910, 0.977, 0.938] | best: 128.3 | elapsed: 00:13:36  (695 steps/s)
# Ep  13000/50000 | avg:    35.6  min:    26.3  max:    45.4 | len:    27 | actor loss:  70.6213 | critic loss:  70.6213 | σ: [0.915, 0.975, 0.934] | best: 128.3 | elapsed: 00:13:41  (537 steps/s)
# Ep  13100/50000 | avg:    36.0  min:    28.1  max:    44.8 | len:    28 | actor loss:  69.3827 | critic loss:  69.3827 | σ: [0.913, 0.978, 0.938] | best: 128.3 | elapsed: 00:13:46  (583 steps/s)
# Ep  13200/50000 | avg:    40.6  min:    32.7  max:    48.7 | len:    33 | actor loss:  72.9819 | critic loss:  72.9819 | σ: [0.918, 0.985, 0.947] | best: 128.3 | elapsed: 00:13:51  (739 steps/s)
# Ep  13300/50000 | avg:    43.5  min:    10.7  max:    85.6 | len:    33 | actor loss:  79.3785 | critic loss:  79.3785 | σ: [0.920, 0.986, 0.941] | best: 128.3 | elapsed: 00:13:56  (643 steps/s)
# Ep  13400/50000 | avg:    42.5  min:     9.3  max:   114.9 | len:    31 | actor loss:  82.5003 | critic loss:  82.5003 | σ: [0.916, 0.983, 0.938] | best: 128.3 | elapsed: 00:14:01  (554 steps/s)
# Ep  13500/50000 | avg:    51.9  min:    34.7  max:   104.1 | len:    35 | actor loss: 100.4137 | critic loss: 100.4137 | σ: [0.915, 0.980, 0.932] | best: 128.3 | elapsed: 00:14:06  (729 steps/s)
# Ep  13600/50000 | avg:    47.4  min:    32.5  max:   114.1 | len:    32 | actor loss:  93.7753 | critic loss:  93.7753 | σ: [0.912, 0.972, 0.930] | best: 128.3 | elapsed: 00:14:11  (627 steps/s)
# Ep  13700/50000 | avg:    51.7  min:    33.3  max:   101.3 | len:    33 | actor loss: 104.2956 | critic loss: 104.2956 | σ: [0.899, 0.973, 0.943] | best: 128.3 | elapsed: 00:14:17  (557 steps/s)
# Ep  13800/50000 | avg:    48.4  min:     8.6  max:   134.1 | len:    32 | actor loss:  96.2303 | critic loss:  96.2303 | σ: [0.889, 0.972, 0.932] | best: 128.3 | elapsed: 00:14:22  (723 steps/s)
# Ep  13900/50000 | avg:    63.7  min:    33.8  max:   116.7 | len:    40 | actor loss: 124.7240 | critic loss: 124.7240 | σ: [0.888, 0.970, 0.931] | best: 128.3 | elapsed: 00:14:28  (612 steps/s)
# Ep  14000/50000 | avg:    57.7  min:     9.8  max:   127.1 | len:    38 | actor loss: 112.3534 | critic loss: 112.3534 | σ: [0.892, 0.961, 0.933] | best: 128.3 | elapsed: 00:14:34  (652 steps/s)
# Ep  14100/50000 | avg:    61.0  min:    10.8  max:   132.8 | len:    39 | actor loss: 119.9632 | critic loss: 119.9632 | σ: [0.898, 0.972, 0.939] | best: 128.3 | elapsed: 00:14:39  (758 steps/s)
# Ep  14200/50000 | avg:    56.2  min:    10.6  max:   172.2 | len:    37 | actor loss: 111.0109 | critic loss: 111.0109 | σ: [0.890, 0.980, 0.941] | best: 128.3 | elapsed: 00:14:46  (534 steps/s)
# Ep  14300/50000 | avg:    52.7  min:    10.3  max:   114.5 | len:    36 | actor loss: 105.8379 | critic loss: 105.8379 | σ: [0.897, 0.978, 0.944] | best: 128.3 | elapsed: 00:14:51  (730 steps/s)
# Ep  14400/50000 | avg:    59.0  min:    10.1  max:   220.4 | len:    39 | actor loss: 115.7301 | critic loss: 115.7301 | σ: [0.895, 0.989, 0.951] | best: 128.3 | elapsed: 00:14:57  (711 steps/s)
# Ep  14500/50000 | avg:    53.9  min:     8.7  max:   217.0 | len:    36 | actor loss: 106.3866 | critic loss: 106.3866 | σ: [0.890, 0.994, 0.952] | best: 128.3 | elapsed: 00:15:03  (555 steps/s)
# Ep  14600/50000 | avg:    60.7  min:     9.2  max:   172.2 | len:    39 | actor loss: 121.1113 | critic loss: 121.1113 | σ: [0.889, 0.989, 0.951] | best: 128.3 | elapsed: 00:15:09  (681 steps/s)
# Ep  14700/50000 | avg:    61.5  min:     8.9  max:   169.3 | len:    40 | actor loss: 119.0975 | critic loss: 119.0975 | σ: [0.888, 0.983, 0.942] | best: 128.3 | elapsed: 00:15:16  (579 steps/s)
# Ep  14800/50000 | avg:    57.4  min:     9.4  max:   107.2 | len:    37 | actor loss: 114.6193 | critic loss: 114.6193 | σ: [0.878, 0.989, 0.944] | best: 128.3 | elapsed: 00:15:21  (681 steps/s)
# Ep  14900/50000 | avg:    66.7  min:     7.6  max:   173.9 | len:    42 | actor loss: 128.0661 | critic loss: 128.0661 | σ: [0.870, 0.987, 0.943] | best: 128.3 | elapsed: 00:15:27  (684 steps/s)
# Ep  15000/50000 | avg:    69.5  min:     9.6  max:   148.9 | len:    43 | actor loss: 134.0894 | critic loss: 134.0894 | σ: [0.863, 0.996, 0.935] | best: 128.3 | elapsed: 00:15:35  (580 steps/s)
# Ep  15100/50000 | avg:    66.7  min:    10.6  max:   162.4 | len:    42 | actor loss: 128.5035 | critic loss: 128.5035 | σ: [0.861, 0.987, 0.927] | best: 128.3 | elapsed: 00:15:41  (702 steps/s)
# Ep  15200/50000 | avg:    59.2  min:     9.7  max:   133.2 | len:    39 | actor loss: 117.2480 | critic loss: 117.2480 | σ: [0.865, 0.995, 0.929] | best: 128.3 | elapsed: 00:15:47  (562 steps/s)
# Ep  15300/50000 | avg:    64.1  min:    32.1  max:   122.0 | len:    41 | actor loss: 124.3705 | critic loss: 124.3705 | σ: [0.861, 0.994, 0.920] | best: 128.3 | elapsed: 00:15:53  (748 steps/s)
# Ep  15400/50000 | avg:    58.8  min:    10.0  max:   128.6 | len:    38 | actor loss: 117.3253 | critic loss: 117.3253 | σ: [0.856, 0.996, 0.925] | best: 128.3 | elapsed: 00:15:58  (707 steps/s)
# Ep  15500/50000 | avg:    43.9  min:     9.8  max:   179.7 | len:    33 | actor loss:  88.8201 | critic loss:  88.8201 | σ: [0.856, 0.988, 0.932] | best: 128.3 | elapsed: 00:16:04  (545 steps/s)
# Ep  15600/50000 | avg:    36.2  min:     9.1  max:   110.2 | len:    28 | actor loss:  72.1615 | critic loss:  72.1615 | σ: [0.859, 0.987, 0.933] | best: 128.3 | elapsed: 00:16:08  (747 steps/s)
# Ep  15700/50000 | avg:    68.2  min:    11.1  max:   199.9 | len:    43 | actor loss: 130.4686 | critic loss: 130.4686 | σ: [0.859, 0.981, 0.928] | best: 128.3 | elapsed: 00:16:14  (696 steps/s)
# Ep  15800/50000 | avg:    70.5  min:    38.9  max:   175.9 | len:    44 | actor loss: 137.2367 | critic loss: 137.2367 | σ: [0.866, 0.985, 0.925] | best: 128.3 | elapsed: 00:16:22  (606 steps/s)
# Ep  15900/50000 | avg:    66.8  min:    12.4  max:   193.0 | len:    41 | actor loss: 132.9777 | critic loss: 132.9777 | σ: [0.872, 0.984, 0.918] | best: 128.3 | elapsed: 00:16:27  (781 steps/s)
# Ep  16000/50000 | avg:    65.6  min:    13.6  max:   109.0 | len:    40 | actor loss: 133.0764 | critic loss: 133.0764 | σ: [0.879, 0.994, 0.916] | best: 128.3 | elapsed: 00:16:34  (565 steps/s)
# Ep  16100/50000 | avg:    66.2  min:     0.7  max:   116.4 | len:    41 | actor loss: 129.9276 | critic loss: 129.9276 | σ: [0.873, 0.983, 0.923] | best: 128.3 | elapsed: 00:16:39  (777 steps/s)
# Ep  16200/50000 | avg:    69.8  min:    38.0  max:   133.7 | len:    42 | actor loss: 137.5218 | critic loss: 137.5218 | σ: [0.879, 0.987, 0.921] | best: 128.3 | elapsed: 00:16:45  (685 steps/s)
# Ep  16300/50000 | avg:    66.9  min:    36.9  max:   105.3 | len:    42 | actor loss: 132.0006 | critic loss: 132.0006 | σ: [0.883, 0.986, 0.923] | best: 128.3 | elapsed: 00:16:52  (617 steps/s)
# Ep  16400/50000 | avg:    66.2  min:    38.3  max:   112.3 | len:    41 | actor loss: 130.1027 | critic loss: 130.1027 | σ: [0.885, 0.985, 0.918] | best: 128.3 | elapsed: 00:16:57  (775 steps/s)
# Ep  16500/50000 | avg:    61.0  min:    34.0  max:   113.4 | len:    38 | actor loss: 119.9558 | critic loss: 119.9558 | σ: [0.877, 0.983, 0.908] | best: 128.3 | elapsed: 00:17:04  (583 steps/s)
# Ep  16600/50000 | avg:    64.2  min:    36.8  max:   153.0 | len:    40 | actor loss: 124.1055 | critic loss: 124.1055 | σ: [0.873, 0.972, 0.901] | best: 128.3 | elapsed: 00:17:09  (708 steps/s)
# Ep  16700/50000 | avg:    71.8  min:    35.9  max:   132.4 | len:    44 | actor loss: 136.4746 | critic loss: 136.4746 | σ: [0.870, 0.970, 0.900] | best: 128.3 | elapsed: 00:17:15  (728 steps/s)
# Ep  16800/50000 | avg:    67.9  min:    34.1  max:   179.6 | len:    41 | actor loss: 129.4243 | critic loss: 129.4243 | σ: [0.862, 0.965, 0.900] | best: 128.3 | elapsed: 00:17:22  (589 steps/s)
# Ep  16900/50000 | avg:    61.7  min:    35.4  max:   125.7 | len:    38 | actor loss: 122.8566 | critic loss: 122.8566 | σ: [0.869, 0.973, 0.906] | best: 128.3 | elapsed: 00:17:28  (750 steps/s)
# Ep  17000/50000 | avg:    61.8  min:    34.4  max:   156.3 | len:    38 | actor loss: 121.5393 | critic loss: 121.5393 | σ: [0.862, 0.964, 0.908] | best: 128.3 | elapsed: 00:17:34  (578 steps/s)
# Ep  17100/50000 | avg:    66.1  min:    36.6  max:   174.4 | len:    39 | actor loss: 129.5905 | critic loss: 129.5905 | σ: [0.855, 0.966, 0.907] | best: 128.3 | elapsed: 00:17:40  (626 steps/s)
# Ep  17200/50000 | avg:    78.4  min:    34.9  max:   160.9 | len:    47 | actor loss: 146.5684 | critic loss: 146.5684 | σ: [0.854, 0.978, 0.909] | best: 128.3 | elapsed: 00:17:47  (665 steps/s)
# Ep  17300/50000 | avg:    78.2  min:    40.8  max:   152.9 | len:    47 | actor loss: 147.9050 | critic loss: 147.9050 | σ: [0.866, 0.986, 0.905] | best: 128.3 | elapsed: 00:17:55  (644 steps/s)
# Ep  17400/50000 | avg:    66.9  min:    36.3  max:   142.4 | len:    41 | actor loss: 132.1890 | critic loss: 132.1890 | σ: [0.873, 0.988, 0.902] | best: 128.3 | elapsed: 00:18:00  (772 steps/s)
# Ep  17500/50000 | avg:    62.2  min:     1.4  max:   126.1 | len:    41 | actor loss: 122.9861 | critic loss: 122.9861 | σ: [0.876, 0.991, 0.902] | best: 128.3 | elapsed: 00:18:07  (556 steps/s)
# Ep  17600/50000 | avg:    67.2  min:     1.7  max:   132.9 | len:    42 | actor loss: 132.2317 | critic loss: 132.2317 | σ: [0.870, 0.991, 0.896] | best: 128.3 | elapsed: 00:18:13  (759 steps/s)
# Ep  17700/50000 | avg:    74.2  min:     2.8  max:   164.0 | len:    46 | actor loss: 141.2705 | critic loss: 141.2705 | σ: [0.855, 0.984, 0.897] | best: 128.3 | elapsed: 00:18:20  (632 steps/s)
# Ep  17800/50000 | avg:    73.3  min:    37.8  max:   169.8 | len:    44 | actor loss: 141.5885 | critic loss: 141.5885 | σ: [0.849, 0.977, 0.906] | best: 128.3 | elapsed: 00:18:27  (681 steps/s)
# Ep  17900/50000 | avg:    60.0  min:    37.1  max:   171.2 | len:    37 | actor loss: 121.5714 | critic loss: 121.5714 | σ: [0.847, 0.983, 0.914] | best: 128.3 | elapsed: 00:18:32  (755 steps/s)
# Ep  18000/50000 | avg:    57.0  min:     4.9  max:   117.9 | len:    38 | actor loss: 113.2099 | critic loss: 113.2099 | σ: [0.850, 0.984, 0.919] | best: 128.3 | elapsed: 00:18:38  (559 steps/s)
# Ep  18100/50000 | avg:    71.4  min:     2.8  max:   175.6 | len:    44 | actor loss: 140.4607 | critic loss: 140.4607 | σ: [0.846, 0.994, 0.921] | best: 128.3 | elapsed: 00:18:44  (759 steps/s)
# Ep  18200/50000 | avg:    75.7  min:    17.4  max:   143.6 | len:    46 | actor loss: 149.6988 | critic loss: 149.6988 | σ: [0.849, 0.988, 0.922] | best: 128.3 | elapsed: 00:18:52  (566 steps/s)
# Ep  18300/50000 | avg:    78.9  min:    14.3  max:   165.9 | len:    49 | actor loss: 152.1067 | critic loss: 152.1067 | σ: [0.841, 0.988, 0.919] | best: 128.3 | elapsed: 00:18:59  (722 steps/s)
# Ep  18400/50000 | avg:    77.5  min:     4.4  max:   163.0 | len:    52 | actor loss: 144.6073 | critic loss: 144.6073 | σ: [0.845, 0.981, 0.911] | best: 128.3 | elapsed: 00:19:07  (657 steps/s)
# Ep  18500/50000 | avg:    68.4  min:     2.9  max:   166.1 | len:    50 | actor loss: 127.5099 | critic loss: 127.5099 | σ: [0.848, 0.984, 0.908] | best: 128.3 | elapsed: 00:19:14  (717 steps/s)
# Ep  18600/50000 | avg:    81.4  min:     1.5  max:   234.2 | len:    54 | actor loss: 152.1551 | critic loss: 152.1551 | σ: [0.854, 0.986, 0.906] | best: 128.3 | elapsed: 00:19:24  (555 steps/s)
# Ep  18700/50000 | avg:    97.5  min:     1.4  max:   255.1 | len:    60 | actor loss: 181.1406 | critic loss: 181.1406 | σ: [0.857, 0.994, 0.901] | best: 128.3 | elapsed: 00:19:32  (770 steps/s)
# Ep  18800/50000 | avg:    93.9  min:     2.2  max:   268.3 | len:    59 | actor loss: 173.8384 | critic loss: 173.8384 | σ: [0.857, 1.000, 0.909] | best: 128.3 | elapsed: 00:19:42  (598 steps/s)
# Ep  18900/50000 | avg:    94.9  min:     1.2  max:   205.0 | len:    59 | actor loss: 178.6375 | critic loss: 178.6375 | σ: [0.856, 1.004, 0.913] | best: 128.3 | elapsed: 00:19:50  (706 steps/s)
# Ep  19000/50000 | avg:    94.1  min:     2.1  max:   203.5 | len:    61 | actor loss: 176.2622 | critic loss: 176.2622 | σ: [0.858, 1.013, 0.917] | best: 128.3 | elapsed: 00:20:00  (597 steps/s)
# Ep  19100/50000 | avg:    79.6  min:     2.2  max:   168.2 | len:    54 | actor loss: 152.9447 | critic loss: 152.9447 | σ: [0.863, 1.011, 0.921] | best: 128.3 | elapsed: 00:20:08  (673 steps/s)
# Ep  19200/50000 | avg:    73.7  min:     3.4  max:   164.7 | len:    52 | actor loss: 142.1422 | critic loss: 142.1422 | σ: [0.866, 1.012, 0.919] | best: 128.3 | elapsed: 00:20:16  (678 steps/s)
# Ep  19300/50000 | avg:    80.1  min:    43.8  max:   193.9 | len:    54 | actor loss: 154.0026 | critic loss: 154.0026 | σ: [0.869, 1.007, 0.921] | best: 128.3 | elapsed: 00:20:24  (656 steps/s)
# Ep  19400/50000 | avg:    94.6  min:     1.8  max:   211.8 | len:    59 | actor loss: 177.8257 | critic loss: 177.8257 | σ: [0.867, 1.016, 0.926] | best: 128.3 | elapsed: 00:20:32  (713 steps/s)
# Ep  19500/50000 | avg:   115.9  min:    51.5  max:   230.1 | len:    66 | actor loss: 216.7011 | critic loss: 216.7011 | σ: [0.876, 1.014, 0.926] | best: 128.3 | elapsed: 00:20:43  (639 steps/s)
# Ep  19600/50000 | avg:   111.4  min:    54.0  max:   219.0 | len:    65 | actor loss: 206.7324 | critic loss: 206.7324 | σ: [0.884, 1.011, 0.926] | best: 128.3 | elapsed: 00:20:51  (791 steps/s)
# Ep  19700/50000 | avg:   101.6  min:    26.7  max:   313.9 | len:    62 | actor loss: 184.9817 | critic loss: 184.9817 | σ: [0.888, 1.013, 0.928] | best: 128.3 | elapsed: 00:21:01  (639 steps/s)
# Ep  19800/50000 | avg:    95.2  min:     0.2  max:   216.9 | len:    57 | actor loss: 175.7852 | critic loss: 175.7852 | σ: [0.880, 1.020, 0.938] | best: 128.3 | elapsed: 00:21:09  (704 steps/s)
# Ep  19900/50000 | avg:    88.1  min:    41.2  max:   183.3 | len:    54 | actor loss: 164.2894 | critic loss: 164.2894 | σ: [0.869, 1.017, 0.933] | best: 128.3 | elapsed: 00:21:17  (650 steps/s)
# Ep  20000/50000 | avg:    90.7  min:    44.1  max:   194.9 | len:    55 | actor loss: 169.2060 | critic loss: 169.2060 | σ: [0.873, 1.014, 0.942] | best: 128.3 | elapsed: 00:21:25  (699 steps/s)
# Ep  20100/50000 | avg:    80.4  min:    37.7  max:   148.8 | len:    51 | actor loss: 150.1100 | critic loss: 150.1100 | σ: [0.870, 1.018, 0.945] | best: 128.3 | elapsed: 00:21:32  (670 steps/s)
# Ep  20200/50000 | avg:    82.1  min:     1.9  max:   143.4 | len:    51 | actor loss: 153.5615 | critic loss: 153.5615 | σ: [0.876, 1.013, 0.953] | best: 128.3 | elapsed: 00:21:40  (725 steps/s)
# Ep  20300/50000 | avg:    77.4  min:    13.8  max:   157.8 | len:    50 | actor loss: 143.2077 | critic loss: 143.2077 | σ: [0.887, 1.011, 0.952] | best: 128.3 | elapsed: 00:21:47  (646 steps/s)
# Ep  20400/50000 | avg:    74.9  min:    39.2  max:   167.9 | len:    49 | actor loss: 141.8938 | critic loss: 141.8938 | σ: [0.901, 1.007, 0.949] | best: 128.3 | elapsed: 00:21:54  (731 steps/s)
# Ep  20500/50000 | avg:    75.6  min:    42.1  max:   101.2 | len:    50 | actor loss: 142.5858 | critic loss: 142.5858 | σ: [0.906, 1.010, 0.950] | best: 128.3 | elapsed: 00:22:02  (624 steps/s)
# Ep  20600/50000 | avg:    85.3  min:    48.0  max:   112.0 | len:    54 | actor loss: 162.0273 | critic loss: 162.0273 | σ: [0.906, 1.009, 0.954] | best: 128.3 | elapsed: 00:22:09  (759 steps/s)
# Ep  20700/50000 | avg:    83.2  min:    41.2  max:   100.7 | len:    53 | actor loss: 156.5111 | critic loss: 156.5111 | σ: [0.902, 1.008, 0.946] | best: 128.3 | elapsed: 00:22:18  (622 steps/s)
# Ep  20800/50000 | avg:    78.9  min:    37.6  max:    94.3 | len:    49 | actor loss: 152.0216 | critic loss: 152.0216 | σ: [0.894, 1.004, 0.947] | best: 128.3 | elapsed: 00:22:24  (792 steps/s)
# Ep  20900/50000 | avg:    78.8  min:    38.9  max:    89.3 | len:    49 | actor loss: 151.6828 | critic loss: 151.6828 | σ: [0.883, 0.999, 0.950] | best: 128.3 | elapsed: 00:22:32  (602 steps/s)
# Ep  21000/50000 | avg:    81.5  min:    41.9  max:    90.1 | len:    51 | actor loss: 157.4956 | critic loss: 157.4956 | σ: [0.880, 1.001, 0.955] | best: 128.3 | elapsed: 00:22:39  (777 steps/s)
# Ep  21100/50000 | avg:    78.1  min:    32.1  max:    91.9 | len:    49 | actor loss: 150.2515 | critic loss: 150.2515 | σ: [0.879, 1.001, 0.948] | best: 128.3 | elapsed: 00:22:47  (589 steps/s)
# Ep  21200/50000 | avg:    70.6  min:    -4.1  max:   106.4 | len:    47 | actor loss: 133.1669 | critic loss: 133.1669 | σ: [0.880, 0.995, 0.951] | best: 128.3 | elapsed: 00:22:53  (769 steps/s)
# Ep  21300/50000 | avg:    74.5  min:    -2.8  max:   147.4 | len:    50 | actor loss: 140.1650 | critic loss: 140.1650 | σ: [0.883, 0.996, 0.948] | best: 128.3 | elapsed: 00:23:02  (578 steps/s)
# Ep  21400/50000 | avg:    75.8  min:    -4.7  max:   221.7 | len:    48 | actor loss: 146.6140 | critic loss: 146.6140 | σ: [0.886, 1.000, 0.933] | best: 128.3 | elapsed: 00:23:08  (772 steps/s)
# Ep  21500/50000 | avg:    77.7  min:    -4.9  max:   140.1 | len:    51 | actor loss: 144.3906 | critic loss: 144.3906 | σ: [0.883, 1.008, 0.928] | best: 128.3 | elapsed: 00:23:17  (598 steps/s)
# Ep  21600/50000 | avg:    79.6  min:    -3.8  max:   125.5 | len:    51 | actor loss: 152.0388 | critic loss: 152.0388 | σ: [0.868, 1.007, 0.928] | best: 128.3 | elapsed: 00:23:23  (782 steps/s)
# Ep  21700/50000 | avg:    76.4  min:    42.4  max:   111.7 | len:    50 | actor loss: 143.8309 | critic loss: 143.8309 | σ: [0.858, 1.005, 0.929] | best: 128.3 | elapsed: 00:23:31  (614 steps/s)
# Ep  21800/50000 | avg:    77.1  min:    45.1  max:    98.8 | len:    50 | actor loss: 149.4773 | critic loss: 149.4773 | σ: [0.864, 1.016, 0.934] | best: 128.3 | elapsed: 00:23:38  (766 steps/s)
# Ep  21900/50000 | avg:    75.0  min:    -4.2  max:    94.7 | len:    49 | actor loss: 146.2555 | critic loss: 146.2555 | σ: [0.862, 1.023, 0.940] | best: 128.3 | elapsed: 00:23:46  (634 steps/s)
# Ep  22000/50000 | avg:    72.6  min:    -2.7  max:    88.5 | len:    47 | actor loss: 141.0712 | critic loss: 141.0712 | σ: [0.860, 1.024, 0.944] | best: 128.3 | elapsed: 00:23:53  (672 steps/s)
# Ep  22100/50000 | avg:    76.7  min:    45.1  max:    87.1 | len:    49 | actor loss: 147.5003 | critic loss: 147.5003 | σ: [0.857, 1.020, 0.938] | best: 128.3 | elapsed: 00:24:00  (632 steps/s)
# Ep  22200/50000 | avg:    77.4  min:    70.5  max:    93.3 | len:    49 | actor loss: 148.1513 | critic loss: 148.1513 | σ: [0.862, 1.010, 0.931] | best: 128.3 | elapsed: 00:24:07  (688 steps/s)
# Ep  22300/50000 | avg:    75.4  min:    67.9  max:    93.7 | len:    49 | actor loss: 144.4308 | critic loss: 144.4308 | σ: [0.862, 1.010, 0.930] | best: 128.3 | elapsed: 00:24:14  (700 steps/s)
# Ep  22400/50000 | avg:    76.6  min:    42.8  max:    82.3 | len:    49 | actor loss: 147.3801 | critic loss: 147.3801 | σ: [0.864, 1.012, 0.918] | best: 128.3 | elapsed: 00:24:22  (651 steps/s)
# Ep  22500/50000 | avg:    78.4  min:    37.9  max:    88.6 | len:    50 | actor loss: 150.6218 | critic loss: 150.6218 | σ: [0.860, 1.010, 0.915] | best: 128.3 | elapsed: 00:24:29  (733 steps/s)
# Ep  22600/50000 | avg:    81.8  min:    39.2  max:   147.8 | len:    53 | actor loss: 153.8125 | critic loss: 153.8125 | σ: [0.865, 1.000, 0.910] | best: 128.3 | elapsed: 00:24:37  (644 steps/s)
# Ep  22700/50000 | avg:    79.4  min:    38.7  max:   112.6 | len:    52 | actor loss: 145.9907 | critic loss: 145.9907 | σ: [0.873, 0.988, 0.902] | best: 128.3 | elapsed: 00:24:44  (755 steps/s)
# Ep  22800/50000 | avg:    60.6  min:    37.4  max:   133.5 | len:    44 | actor loss: 105.2274 | critic loss: 105.2274 | σ: [0.874, 0.986, 0.905] | best: 128.3 | elapsed: 00:24:51  (610 steps/s)
# Ep  22900/50000 | avg:    69.9  min:    37.6  max:   118.0 | len:    48 | actor loss: 129.6913 | critic loss: 129.6913 | σ: [0.871, 0.994, 0.912] | best: 128.3 | elapsed: 00:24:57  (771 steps/s)
# Ep  23000/50000 | avg:    78.7  min:     2.2  max:   138.2 | len:    50 | actor loss: 148.1742 | critic loss: 148.1742 | σ: [0.867, 0.987, 0.910] | best: 128.3 | elapsed: 00:25:05  (609 steps/s)
# Ep  23100/50000 | avg:    62.2  min:    -0.7  max:   113.6 | len:    40 | actor loss: 124.1831 | critic loss: 124.1831 | σ: [0.867, 0.975, 0.908] | best: 128.3 | elapsed: 00:25:11  (792 steps/s)
# Ep  23200/50000 | avg:    52.3  min:     0.0  max:   106.3 | len:    36 | actor loss: 109.0500 | critic loss: 109.0500 | σ: [0.870, 0.980, 0.907] | best: 128.3 | elapsed: 00:25:16  (646 steps/s)
# Ep  23300/50000 | avg:    50.4  min:    -0.7  max:   109.5 | len:    36 | actor loss: 103.9518 | critic loss: 103.9518 | σ: [0.869, 0.976, 0.906] | best: 128.3 | elapsed: 00:25:22  (649 steps/s)
# Ep  23400/50000 | avg:    39.6  min:    -1.0  max:    98.7 | len:    31 | actor loss:  85.3665 | critic loss:  85.3665 | σ: [0.866, 0.975, 0.908] | best: 128.3 | elapsed: 00:25:26  (738 steps/s)
# Ep  23500/50000 | avg:    45.6  min:    -0.5  max:   101.8 | len:    33 | actor loss:  96.8000 | critic loss:  96.8000 | σ: [0.874, 0.966, 0.906] | best: 128.3 | elapsed: 00:25:31  (627 steps/s)
# Ep  23600/50000 | avg:    63.2  min:     0.6  max:   127.9 | len:    41 | actor loss: 128.1828 | critic loss: 128.1828 | σ: [0.879, 0.959, 0.912] | best: 128.3 | elapsed: 00:25:38  (647 steps/s)
# Ep  23700/50000 | avg:    54.3  min:     2.1  max:   153.2 | len:    37 | actor loss: 115.0572 | critic loss: 115.0572 | σ: [0.881, 0.965, 0.911] | best: 128.3 | elapsed: 00:25:42  (748 steps/s)
# Ep  23800/50000 | avg:    49.0  min:    38.4  max:   195.9 | len:    31 | actor loss: 108.9084 | critic loss: 108.9084 | σ: [0.891, 0.972, 0.902] | best: 128.3 | elapsed: 00:25:48  (575 steps/s)
# Ep  23900/50000 | avg:    52.0  min:    38.6  max:   170.2 | len:    33 | actor loss: 111.7027 | critic loss: 111.7027 | σ: [0.888, 0.970, 0.900] | best: 128.3 | elapsed: 00:25:53  (658 steps/s)
# Ep  24000/50000 | avg:    64.8  min:    37.5  max:   191.6 | len:    39 | actor loss: 129.7141 | critic loss: 129.7141 | σ: [0.882, 0.975, 0.902] | best: 128.3 | elapsed: 00:25:58  (751 steps/s)
# Ep  24100/50000 | avg:    79.9  min:    38.8  max:   173.1 | len:    48 | actor loss: 149.8859 | critic loss: 149.8859 | σ: [0.882, 0.971, 0.899] | best: 128.3 | elapsed: 00:26:06  (576 steps/s)
# Ep  24200/50000 | avg:    73.6  min:    37.0  max:   201.2 | len:    43 | actor loss: 143.3342 | critic loss: 143.3342 | σ: [0.881, 0.969, 0.901] | best: 128.3 | elapsed: 00:26:12  (750 steps/s)
# Ep  24300/50000 | avg:    63.8  min:    39.4  max:   213.3 | len:    38 | actor loss: 129.8758 | critic loss: 129.8758 | σ: [0.887, 0.976, 0.903] | best: 128.3 | elapsed: 00:26:18  (635 steps/s)
# ...
#   → New best! Saved to reinforce_best_ep27800_avg183.pt
# Ep  27900/50000 | avg:   169.4  min:    51.4  max:   265.2 | len:    93 | actor loss: 279.8475 | critic loss: 279.8475 | σ: [0.883, 1.019, 0.913] | best: 183.4 | elapsed: 00:32:05  (696 steps/s)
# Ep  28000/50000 | avg:   186.5  min:    63.6  max:   274.2 | len:    99 | actor loss: 308.3228 | critic loss: 308.3228 | σ: [0.881, 1.020, 0.898] | best: 183.4 | elapsed: 00:32:19  (699 steps/s)
#   → New best! Saved to reinforce_best_ep28000_avg186.pt
# Ep  28100/50000 | avg:   199.0  min:    71.3  max:   271.7 | len:   108 | actor loss: 321.3914 | critic loss: 321.3914 | σ: [0.886, 1.027, 0.895] | best: 186.5 | elapsed: 00:32:35  (713 steps/s)
#   → New best! Saved to reinforce_best_ep28100_avg199.pt
# Ep  28200/50000 | avg:   181.6  min:    55.4  max:   310.7 | len:   101 | actor loss: 294.3705 | critic loss: 294.3705 | σ: [0.884, 1.027, 0.902] | best: 199.0 | elapsed: 00:32:49  (705 steps/s)
# Ep  28300/50000 | avg:   186.1  min:    64.0  max:   265.1 | len:    98 | actor loss: 309.4871 | critic loss: 309.4871 | σ: [0.894, 1.029, 0.898] | best: 199.0 | elapsed: 00:33:03  (702 steps/s)
# Ep  28400/50000 | avg:   162.6  min:    46.8  max:   259.0 | len:    90 | actor loss: 273.4044 | critic loss: 273.4044 | σ: [0.897, 1.031, 0.900] | best: 199.0 | elapsed: 00:33:16  (680 steps/s)
# Ep  28500/50000 | avg:   165.0  min:    48.7  max:   354.6 | len:    90 | actor loss: 278.8594 | critic loss: 278.8594 | σ: [0.896, 1.036, 0.913] | best: 199.0 | elapsed: 00:33:28  (765 steps/s)
# Ep  28600/50000 | avg:   186.3  min:    65.5  max:   274.1 | len:   100 | actor loss: 309.2287 | critic loss: 309.2287 | σ: [0.897, 1.031, 0.918] | best: 199.0 | elapsed: 00:33:42  (729 steps/s)
# Ep  28700/50000 | avg:   185.0  min:    49.3  max:   388.8 | len:   101 | actor loss: 298.0968 | critic loss: 298.0968 | σ: [0.905, 1.026, 0.908] | best: 199.0 | elapsed: 00:33:56  (681 steps/s)
# Ep  28800/50000 | avg:   211.4  min:    48.6  max:   401.9 | len:   116 | actor loss: 329.6900 | critic loss: 329.6900 | σ: [0.913, 1.037, 0.901] | best: 199.0 | elapsed: 00:34:13  (688 steps/s)
#   → New best! Saved to reinforce_best_ep28800_avg211.pt
# Ep  28900/50000 | avg:   229.8  min:   108.9  max:   381.3 | len:   128 | actor loss: 351.4272 | critic loss: 351.4272 | σ: [0.917, 1.037, 0.913] | best: 211.4 | elapsed: 00:34:32  (668 steps/s)
#   → New best! Saved to reinforce_best_ep28900_avg230.pt
# Ep  29000/50000 | avg:   222.3  min:   124.1  max:   300.8 | len:   121 | actor loss: 346.9310 | critic loss: 346.9310 | σ: [0.907, 1.038, 0.915] | best: 229.8 | elapsed: 00:34:50  (703 steps/s)
# Ep  29100/50000 | avg:   218.0  min:    99.3  max:   396.3 | len:   113 | actor loss: 355.8445 | critic loss: 355.8445 | σ: [0.908, 1.046, 0.917] | best: 229.8 | elapsed: 00:35:06  (703 steps/s)
# Ep  29200/50000 | avg:   210.2  min:    69.1  max:   363.6 | len:   109 | actor loss: 347.6464 | critic loss: 347.6464 | σ: [0.911, 1.050, 0.923] | best: 229.8 | elapsed: 00:35:21  (715 steps/s)
# Ep  29300/50000 | avg:   224.6  min:    92.7  max:   448.0 | len:   114 | actor loss: 363.7985 | critic loss: 363.7985 | σ: [0.903, 1.049, 0.915] | best: 229.8 | elapsed: 00:35:37  (719 steps/s)
# Ep  29400/50000 | avg:   221.5  min:    55.7  max:   371.6 | len:   116 | actor loss: 353.5294 | critic loss: 353.5294 | σ: [0.901, 1.052, 0.921] | best: 229.8 | elapsed: 00:35:53  (717 steps/s)
# Ep  29500/50000 | avg:   179.1  min:    51.5  max:   412.5 | len:    98 | actor loss: 290.3447 | critic loss: 290.3447 | σ: [0.888, 1.052, 0.921] | best: 229.8 | elapsed: 00:36:07  (711 steps/s)
# Ep  29600/50000 | avg:   121.1  min:    53.2  max:   290.6 | len:    72 | actor loss: 209.6035 | critic loss: 209.6035 | σ: [0.885, 1.046, 0.927] | best: 229.8 | elapsed: 00:36:16  (787 steps/s)
# Ep  29700/50000 | avg:   114.9  min:    49.6  max:   245.3 | len:    71 | actor loss: 197.2363 | critic loss: 197.2363 | σ: [0.885, 1.036, 0.927] | best: 229.8 | elapsed: 00:36:26  (667 steps/s)
# Ep  29800/50000 | avg:   193.6  min:    54.9  max:   434.1 | len:   109 | actor loss: 305.3877 | critic loss: 305.3877 | σ: [0.888, 1.041, 0.935] | best: 229.8 | elapsed: 00:36:42  (716 steps/s)
# Ep  29900/50000 | avg:   209.7  min:    56.4  max:   400.9 | len:   117 | actor loss: 326.0135 | critic loss: 326.0135 | σ: [0.881, 1.046, 0.942] | best: 229.8 | elapsed: 00:36:58  (718 steps/s)
# Ep  30000/50000 | avg:   190.1  min:    53.7  max:   403.8 | len:   103 | actor loss: 310.6832 | critic loss: 310.6832 | σ: [0.885, 1.037, 0.942] | best: 229.8 | elapsed: 00:37:13  (705 steps/s)
# Ep  30100/50000 | avg:   206.9  min:    55.7  max:   449.7 | len:   113 | actor loss: 332.3881 | critic loss: 332.3881 | σ: [0.901, 1.037, 0.941] | best: 229.8 | elapsed: 00:37:28  (729 steps/s)
# Ep  30200/50000 | avg:   211.4  min:    43.9  max:   503.3 | len:   119 | actor loss: 324.2673 | critic loss: 324.2673 | σ: [0.909, 1.040, 0.936] | best: 229.8 | elapsed: 00:37:44  (723 steps/s)
# Ep  30300/50000 | avg:   222.8  min:    53.0  max:   575.3 | len:   125 | actor loss: 334.4334 | critic loss: 334.4334 | σ: [0.905, 1.039, 0.930] | best: 229.8 | elapsed: 00:38:02  (722 steps/s)
# Ep  30400/50000 | avg:   217.9  min:    53.7  max:   444.4 | len:   119 | actor loss: 336.1636 | critic loss: 336.1636 | σ: [0.910, 1.041, 0.925] | best: 229.8 | elapsed: 00:38:18  (720 steps/s)
# Ep  30500/50000 | avg:   202.7  min:    55.9  max:   480.8 | len:   110 | actor loss: 322.6952 | critic loss: 322.6952 | σ: [0.910, 1.040, 0.934] | best: 229.8 | elapsed: 00:38:33  (718 steps/s)
# Ep  30600/50000 | avg:   189.4  min:    51.7  max:   606.6 | len:   102 | actor loss: 305.5647 | critic loss: 305.5647 | σ: [0.902, 1.048, 0.936] | best: 229.8 | elapsed: 00:38:48  (701 steps/s)
# Ep  30700/50000 | avg:   204.2  min:    62.5  max:   358.2 | len:   106 | actor loss: 342.2134 | critic loss: 342.2134 | σ: [0.911, 1.066, 0.948] | best: 229.8 | elapsed: 00:39:03  (708 steps/s)
# Ep  30800/50000 | avg:   209.5  min:    64.7  max:   377.7 | len:   106 | actor loss: 350.6685 | critic loss: 350.6685 | σ: [0.907, 1.059, 0.940] | best: 229.8 | elapsed: 00:39:18  (702 steps/s)
# Ep  30900/50000 | avg:   199.2  min:    55.7  max:   349.2 | len:   104 | actor loss: 332.4701 | critic loss: 332.4701 | σ: [0.897, 1.060, 0.932] | best: 229.8 | elapsed: 00:39:33  (713 steps/s)
# Ep  31000/50000 | avg:   219.7  min:    53.4  max:   710.8 | len:   112 | actor loss: 351.2596 | critic loss: 351.2596 | σ: [0.902, 1.076, 0.922] | best: 229.8 | elapsed: 00:39:48  (724 steps/s)
# Ep  31100/50000 | avg:   206.7  min:    47.7  max:   587.0 | len:   107 | actor loss: 334.8254 | critic loss: 334.8254 | σ: [0.898, 1.083, 0.930] | best: 229.8 | elapsed: 00:40:03  (704 steps/s)
# Ep  31200/50000 | avg:   219.9  min:    15.1  max:   667.1 | len:   117 | actor loss: 329.2658 | critic loss: 329.2658 | σ: [0.898, 1.094, 0.930] | best: 229.8 | elapsed: 00:40:20  (710 steps/s)
# Ep  31300/50000 | avg:   209.7  min:    14.7  max:   516.7 | len:   117 | actor loss: 316.9506 | critic loss: 316.9506 | σ: [0.897, 1.108, 0.927] | best: 229.8 | elapsed: 00:40:36  (732 steps/s)
# Ep  31400/50000 | avg:   226.9  min:    13.5  max:   689.7 | len:   121 | actor loss: 348.4978 | critic loss: 348.4978 | σ: [0.894, 1.099, 0.940] | best: 229.8 | elapsed: 00:40:52  (728 steps/s)
# Ep  31500/50000 | avg:   207.4  min:    30.0  max:   588.5 | len:   115 | actor loss: 318.9224 | critic loss: 318.9224 | σ: [0.890, 1.102, 0.949] | best: 229.8 | elapsed: 00:41:09  (705 steps/s)
# Ep  31600/50000 | avg:   220.9  min:    49.3  max:   591.5 | len:   117 | actor loss: 348.8946 | critic loss: 348.8946 | σ: [0.884, 1.099, 0.956] | best: 229.8 | elapsed: 00:41:26  (685 steps/s)
# Ep  31700/50000 | avg:   175.8  min:    41.1  max:   619.1 | len:   103 | actor loss: 271.8892 | critic loss: 271.8892 | σ: [0.887, 1.111, 0.962] | best: 229.8 | elapsed: 00:41:40  (732 steps/s)
# Ep  31800/50000 | avg:   138.3  min:    40.6  max:   552.3 | len:    84 | actor loss: 230.0336 | critic loss: 230.0336 | σ: [0.895, 1.117, 0.967] | best: 229.8 | elapsed: 00:41:52  (677 steps/s)
# Ep  31900/50000 | avg:   118.9  min:    34.3  max:   458.4 | len:    72 | actor loss: 203.1004 | critic loss: 203.1004 | σ: [0.891, 1.125, 0.971] | best: 229.8 | elapsed: 00:42:03  (659 steps/s)
# Ep  32000/50000 | avg:   123.4  min:    44.0  max:   361.8 | len:    75 | actor loss: 215.1730 | critic loss: 215.1730 | σ: [0.887, 1.127, 0.974] | best: 229.8 | elapsed: 00:42:14  (733 steps/s)
# Ep  32100/50000 | avg:   142.9  min:    42.4  max:   380.9 | len:    85 | actor loss: 239.2939 | critic loss: 239.2939 | σ: [0.891, 1.120, 0.971] | best: 229.8 | elapsed: 00:42:25  (748 steps/s)
# Ep  32200/50000 | avg:   165.7  min:    42.4  max:   417.6 | len:    91 | actor loss: 282.0222 | critic loss: 282.0222 | σ: [0.897, 1.133, 0.963] | best: 229.8 | elapsed: 00:42:38  (701 steps/s)
# Ep  32300/50000 | avg:   202.9  min:    51.3  max:   483.3 | len:   105 | actor loss: 334.3317 | critic loss: 334.3317 | σ: [0.898, 1.132, 0.965] | best: 229.8 | elapsed: 00:42:52  (721 steps/s)
# Ep  32400/50000 | avg:   212.6  min:    42.2  max:   475.2 | len:   106 | actor loss: 359.6552 | critic loss: 359.6552 | σ: [0.901, 1.132, 0.979] | best: 229.8 | elapsed: 00:43:08  (703 steps/s)
# Ep  32500/50000 | avg:   191.9  min:    41.5  max:   479.2 | len:   100 | actor loss: 325.9494 | critic loss: 325.9494 | σ: [0.905, 1.130, 0.983] | best: 229.8 | elapsed: 00:43:22  (711 steps/s)
# Ep  32600/50000 | avg:   198.9  min:    50.4  max:   648.3 | len:   105 | actor loss: 327.1109 | critic loss: 327.1109 | σ: [0.901, 1.127, 0.975] | best: 229.8 | elapsed: 00:43:37  (696 steps/s)
# Ep  32700/50000 | avg:   251.6  min:    49.4  max:   880.2 | len:   123 | actor loss: 393.1083 | critic loss: 393.1083 | σ: [0.896, 1.137, 0.971] | best: 229.8 | elapsed: 00:43:54  (725 steps/s)
#   → New best! Saved to reinforce_best_ep32700_avg252.pt
# Ep  32800/50000 | avg:   227.2  min:    54.6  max:   597.6 | len:   112 | actor loss: 367.8395 | critic loss: 367.8395 | σ: [0.896, 1.134, 0.976] | best: 251.6 | elapsed: 00:44:09  (721 steps/s)
# Ep  32900/50000 | avg:   173.7  min:    46.6  max:   518.7 | len:    89 | actor loss: 290.5455 | critic loss: 290.5455 | σ: [0.893, 1.134, 0.978] | best: 251.6 | elapsed: 00:44:22  (692 steps/s)
# Ep  33000/50000 | avg:   179.4  min:    48.3  max:   599.6 | len:    91 | actor loss: 309.4499 | critic loss: 309.4499 | σ: [0.894, 1.131, 0.976] | best: 251.6 | elapsed: 00:44:35  (709 steps/s)
# Ep  33100/50000 | avg:   138.2  min:    51.4  max:   398.6 | len:    77 | actor loss: 247.5844 | critic loss: 247.5844 | σ: [0.891, 1.130, 0.983] | best: 251.6 | elapsed: 00:44:44  (809 steps/s)
# Ep  33200/50000 | avg:   199.9  min:    51.4  max:   565.9 | len:   102 | actor loss: 331.5637 | critic loss: 331.5637 | σ: [0.893, 1.134, 0.975] | best: 251.6 | elapsed: 00:44:59  (707 steps/s)
# Ep  33300/50000 | avg:   226.2  min:    53.9  max:   640.5 | len:   112 | actor loss: 368.6028 | critic loss: 368.6028 | σ: [0.901, 1.130, 0.972] | best: 251.6 | elapsed: 00:45:14  (715 steps/s)
# Ep  33400/50000 | avg:   213.7  min:    76.0  max:   559.7 | len:   104 | actor loss: 360.5171 | critic loss: 360.5171 | σ: [0.907, 1.132, 0.967] | best: 251.6 | elapsed: 00:45:29  (715 steps/s)
# Ep  33500/50000 | avg:   221.0  min:    78.6  max:   787.5 | len:   110 | actor loss: 362.0084 | critic loss: 362.0084 | σ: [0.908, 1.127, 0.963] | best: 251.6 | elapsed: 00:45:45  (703 steps/s)
# Ep  33600/50000 | avg:   186.1  min:    86.7  max:   574.0 | len:    94 | actor loss: 323.5548 | critic loss: 323.5548 | σ: [0.900, 1.132, 0.955] | best: 251.6 | elapsed: 00:45:58  (684 steps/s)
# Ep  33700/50000 | avg:   188.7  min:    58.6  max:   397.2 | len:    96 | actor loss: 328.7875 | critic loss: 328.7875 | σ: [0.899, 1.127, 0.953] | best: 251.6 | elapsed: 00:46:12  (698 steps/s)
# Ep  33800/50000 | avg:   203.8  min:    75.0  max:   640.0 | len:   102 | actor loss: 338.1354 | critic loss: 338.1354 | σ: [0.900, 1.137, 0.937] | best: 251.6 | elapsed: 00:46:26  (720 steps/s)
# Ep  33900/50000 | avg:   193.3  min:    69.3  max:   603.6 | len:    96 | actor loss: 332.1134 | critic loss: 332.1134 | σ: [0.910, 1.132, 0.934] | best: 251.6 | elapsed: 00:46:39  (722 steps/s)
# Ep  34000/50000 | avg:   221.5  min:    61.7  max:   545.3 | len:   107 | actor loss: 367.9850 | critic loss: 367.9850 | σ: [0.921, 1.130, 0.936] | best: 251.6 | elapsed: 00:46:55  (711 steps/s)
# Ep  34100/50000 | avg:   272.6  min:    80.5  max:   646.3 | len:   128 | actor loss: 426.0615 | critic loss: 426.0615 | σ: [0.920, 1.136, 0.935] | best: 251.6 | elapsed: 00:47:12  (741 steps/s)
#   → New best! Saved to reinforce_best_ep34100_avg273.pt
# Ep  34200/50000 | avg:   257.7  min:    86.4  max:   596.0 | len:   120 | actor loss: 408.0964 | critic loss: 408.0964 | σ: [0.916, 1.131, 0.932] | best: 272.6 | elapsed: 00:47:28  (737 steps/s)
# Ep  34300/50000 | avg:   273.7  min:    75.2  max:   678.1 | len:   130 | actor loss: 427.0990 | critic loss: 427.0990 | σ: [0.918, 1.132, 0.935] | best: 272.6 | elapsed: 00:47:46  (746 steps/s)
#   → New best! Saved to reinforce_best_ep34300_avg274.pt
# Ep  34400/50000 | avg:   281.7  min:    84.8  max:   603.2 | len:   135 | actor loss: 430.2799 | critic loss: 430.2799 | σ: [0.915, 1.133, 0.939] | best: 273.7 | elapsed: 00:48:04  (745 steps/s)
#   → New best! Saved to reinforce_best_ep34400_avg282.pt
# Ep  34500/50000 | avg:   257.0  min:    78.4  max:   656.0 | len:   127 | actor loss: 404.8073 | critic loss: 404.8073 | σ: [0.915, 1.131, 0.937] | best: 281.7 | elapsed: 00:48:21  (715 steps/s)
# Ep  34600/50000 | avg:   250.5  min:    70.0  max:   568.6 | len:   124 | actor loss: 395.3976 | critic loss: 395.3976 | σ: [0.926, 1.134, 0.937] | best: 281.7 | elapsed: 00:48:39  (701 steps/s)
# Ep  34700/50000 | avg:   264.1  min:    69.6  max:   568.3 | len:   128 | actor loss: 421.3150 | critic loss: 421.3150 | σ: [0.923, 1.142, 0.941] | best: 281.7 | elapsed: 00:48:58  (685 steps/s)
# Ep  34800/50000 | avg:   269.2  min:    91.4  max:   511.4 | len:   132 | actor loss: 428.9979 | critic loss: 428.9979 | σ: [0.927, 1.151, 0.936] | best: 281.7 | elapsed: 00:49:16  (723 steps/s)
# Ep  34900/50000 | avg:   257.7  min:    98.2  max:   387.5 | len:   129 | actor loss: 414.0047 | critic loss: 414.0047 | σ: [0.923, 1.161, 0.932] | best: 281.7 | elapsed: 00:49:34  (720 steps/s)
# Ep  35000/50000 | avg:   264.8  min:    73.7  max:   351.4 | len:   132 | actor loss: 423.2421 | critic loss: 423.2421 | σ: [0.932, 1.148, 0.930] | best: 281.7 | elapsed: 00:49:52  (731 steps/s)
# Ep  35100/50000 | avg:   275.5  min:   119.1  max:   380.2 | len:   139 | actor loss: 431.7498 | critic loss: 431.7498 | σ: [0.927, 1.143, 0.925] | best: 281.7 | elapsed: 00:50:12  (683 steps/s)
# Ep  35200/50000 | avg:   271.9  min:   121.9  max:   382.8 | len:   141 | actor loss: 421.2536 | critic loss: 421.2536 | σ: [0.934, 1.138, 0.926] | best: 281.7 | elapsed: 00:50:32  (718 steps/s)
# Ep  35300/50000 | avg:   243.3  min:   120.9  max:   358.3 | len:   132 | actor loss: 383.8201 | critic loss: 383.8201 | σ: [0.933, 1.143, 0.925] | best: 281.7 | elapsed: 00:50:50  (743 steps/s)
# Ep  35400/50000 | avg:   263.5  min:   166.7  max:   353.7 | len:   134 | actor loss: 423.3278 | critic loss: 423.3278 | σ: [0.940, 1.139, 0.925] | best: 281.7 | elapsed: 00:51:08  (735 steps/s)
# Ep  35500/50000 | avg:   245.2  min:    83.6  max:   345.0 | len:   116 | actor loss: 417.4757 | critic loss: 417.4757 | σ: [0.951, 1.127, 0.928] | best: 281.7 | elapsed: 00:51:24  (727 steps/s)
# Ep  35600/50000 | avg:   245.1  min:   121.8  max:   343.8 | len:   123 | actor loss: 406.6159 | critic loss: 406.6159 | σ: [0.944, 1.124, 0.927] | best: 281.7 | elapsed: 00:51:41  (734 steps/s)
# Ep  35700/50000 | avg:   281.8  min:    93.9  max:   401.6 | len:   133 | actor loss: 453.6538 | critic loss: 453.6538 | σ: [0.946, 1.124, 0.918] | best: 281.7 | elapsed: 00:52:00  (684 steps/s)
#   → New best! Saved to reinforce_best_ep35700_avg282.pt

# %%
with open('/content/FAIML-RL-26/part1/agent.py', 'r') as f:
    print('--- agent.py ---')
    print(f.read())

with open('/content/FAIML-RL-26/part1/train.py', 'r') as f:
    print('\n--- train.py ---')
    print(f.read())

# %%
window = min(100, len(ep_rewards))

def moving_avg(data, w):
    return np.convolve(data, np.ones(w) / w, mode='valid')

def moving_std(data, w):
    arr = np.array(data)
    return np.array([arr[i - w + 1 : i + 1].std() for i in range(w - 1, len(arr))])

# ── Smoothed series ──────────────────────────────────────────────────────────
x_smooth = np.arange(window - 1, len(ep_rewards))

reward_smooth = moving_avg(ep_rewards, window)
reward_std    = moving_std(ep_rewards, window)

length_smooth = moving_avg(ep_lengths, window)
length_std    = moving_std(ep_lengths, window)

actor_loss_smooth  = moving_avg(ep_actor_losses,  window) if len(ep_actor_losses)  >= window else np.array(ep_actor_losses)
critic_loss_smooth = moving_avg(ep_critic_losses, window) if len(ep_critic_losses) >= window else np.array(ep_critic_losses)

sigma_eps    = [s[0] for s in sigma_history]
sigma_values = np.array([s[1] for s in sigma_history])   # shape (N_snapshots, n_joints)

baseline_label = (
    'adaptive moving avg'  if BASELINE == -1 else
    'G_t whitening'        if BASELINE == 0  else
    f'fixed constant {BASELINE}'
)

# For REINFORCE, train.py returns actor_loss for both slots → critic loss mirrors actor loss.
# We still plot it so the panel is always present and readable.
critic_label = 'Critic loss' if ALGORITHM == 'actor_critic' else 'Critic loss (= actor loss for REINFORCE)'

fig, axes = plt.subplots(5, 1, figsize=(11, 15), sharex=False)
fig.suptitle(
    f'Training diagnostics  –  {ALGORITHM}  |  baseline: {baseline_label}',
    fontsize=12, fontweight='bold'
)

# ── Panel 1: Episode reward ──────────────────────────────────────────────────
ax = axes[0]
ax.plot(ep_rewards, alpha=0.12, color='steelblue')
ax.fill_between(x_smooth, reward_smooth - reward_std, reward_smooth + reward_std,
                alpha=0.18, color='steelblue', label='±1 std')
ax.plot(x_smooth, reward_smooth, color='steelblue', lw=1.5, label=f'{window}-ep avg')
ax.set_ylabel('Total reward')
ax.legend(fontsize=8); ax.grid(alpha=0.3)

# ── Panel 2: Episode length ──────────────────────────────────────────────────
ax = axes[1]
ax.plot(ep_lengths, alpha=0.12, color='darkorange')
ax.fill_between(x_smooth, length_smooth - length_std, length_smooth + length_std,
                alpha=0.18, color='darkorange', label='±1 std')
ax.plot(x_smooth, length_smooth, color='darkorange', lw=1.5, label=f'{window}-ep avg')
ax.set_ylabel('Steps per episode')
ax.legend(fontsize=8); ax.grid(alpha=0.3)

# ── Panel 3: Actor loss ──────────────────────────────────────────────────────
ax = axes[2]
ax.plot(ep_actor_losses, alpha=0.12, color='crimson')
if len(ep_actor_losses) >= window:
    ax.plot(range(window - 1, len(ep_actor_losses)), actor_loss_smooth,
            color='crimson', lw=1.5, label=f'{window}-ep avg')
ax.set_ylabel('Actor loss')
ax.legend(fontsize=8); ax.grid(alpha=0.3)

# ── Panel 4: Critic loss ─────────────────────────────────────────────────────
ax = axes[3]
ax.plot(ep_critic_losses, alpha=0.12, color='mediumpurple')
if len(ep_critic_losses) >= window:
    ax.plot(range(window - 1, len(ep_critic_losses)), critic_loss_smooth,
            color='mediumpurple', lw=1.5, label=f'{window}-ep avg')
ax.set_ylabel(critic_label)
ax.legend(fontsize=8); ax.grid(alpha=0.3)

# ── Panel 5: σ per joint ─────────────────────────────────────────────────────
ax = axes[4]
colors = ['tab:red', 'tab:green', 'tab:purple']
for j in range(sigma_values.shape[1]):
    ax.plot(sigma_eps, sigma_values[:, j],
            color=colors[j], marker='.', markersize=3, label=f'σ joint {j}')
ax.set_ylabel('σ (after softplus)')
ax.set_xlabel('Episode')
ax.legend(fontsize=8); ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Evaluate Trained Policy
#
# Now we load a saved checkpoint and run the agent **deterministically** (no exploration): instead of sampling from the Gaussian distribution, we just take the mean action at every step.
#
# We also use gymnasium's `RecordVideo` wrapper to save an `.mp4` of the agent so we can watch it.

# %%
# List all .pt files in the checkpoint directory so we can pick one to evaluate
ckpts = sorted([f for f in os.listdir(CHECKPOINT_DIR) if f.endswith('.pt')])
for idx, c in enumerate(ckpts):
    print(f"[{idx}] {c}")

# Change CHECKPOINT_IDX to select a specific checkpoint.
# -1 means the last one in alphabetical order (usually the most recent final checkpoint).
CHECKPOINT_IDX = -1
CHECKPOINT_TO_LOAD = ckpts[CHECKPOINT_IDX] if ckpts else None
print(f"\nSelected: {CHECKPOINT_TO_LOAD}")

# %%
# Import the evaluate() function from test.py.
# Passing video_dir tells it to wrap the env with RecordVideo instead of opening a window –
# useful in Colab where there is no display.
from test import evaluate

# Where to save the recorded .mp4 files
VIDEO_DIR = os.path.join(REPO_ROOT, "part1", "videos")
os.makedirs(VIDEO_DIR, exist_ok=True)

ckpt_path = os.path.join(CHECKPOINT_DIR, CHECKPOINT_TO_LOAD)

# Run 5 deterministic evaluation episodes.
# evaluate() loads the checkpoint, switches to evaluation mode (mean action, no sampling),
# and returns a list with the total reward from each episode.
eval_rewards = evaluate(ckpt_path, num_episodes=5, seed=SEED, video_dir=VIDEO_DIR)

for ep, r in enumerate(eval_rewards, 1):
    print(f"Eval ep {ep}: reward = {r:.2f}")
print(f"\nMean eval reward: {np.mean(eval_rewards):.2f}")

# %%
import base64
from IPython.display import HTML, display as ipy_display

# Find all .mp4 files saved by RecordVideo and display the most recent one inline.
# We encode the video in base64 so it can be embedded directly in the notebook
# without needing a separate file server.
video_files = sorted([f for f in os.listdir(VIDEO_DIR) if f.endswith('.mp4')])

if video_files:
    for i in range(len(video_files)):
      video_path = os.path.join(VIDEO_DIR, video_files[i])
      print(f"Displaying: {video_path}")

      # Read the video file and encode it as base64
      b64 = base64.b64encode(open(video_path, 'rb').read()).decode()

      # Embed the video in an HTML <video> tag
      ipy_display(HTML(
          f'<video width="600" controls autoplay loop>'
          f'<source src="data:video/mp4;base64,{b64}" type="video/mp4">'
          f'</video>'
      ))
else:
    print("No video files found in", VIDEO_DIR)
